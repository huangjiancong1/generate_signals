# %% [markdown]
# # Use AutoEncoding with force_torque_sensor weight initialize
# --------------------------------------------------------------------
#
# Datasets paper: https://arxiv.org/pdf/1807.06749.pdf
#
# Download: https://ibm.ent.box.com/s/vw4y576xlz6ujblpl3gz9c5ttu51qc18

# %%
import numpy as np 

sides_3 = np.load('../data/force_torque_sensor/Dataset/3_sides/Data/data.npy')
# sides_4 = np.load('../data/force_torque_sensor/Dataset/4_sides/Data/data.npy')
# sides_5 = np.load('../data/force_torque_sensor/Dataset/5_sides/Data/data.npy')
# sides_6 = np.load('../data/force_torque_sensor/Dataset/6_sides/Data/data.npy')
# sides_200 = np.load('../data/force_torque_sensor/Dataset/200_sides/Data/data.npy')


import numpy as np 
from collections import namedtuple
from collections import OrderedDict
import numpy as np
import matplotlib.pyplot as plt
# import plotly.graph_objs as go
# import plotly.plotly as py
# import plotly

import os
import time
import torch
import argparse
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from torchvision import transforms
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader
from collections import defaultdict
import torch.nn.functional as F
import torch.nn as nn
from torch.utils.data.sampler import SubsetRandomSampler



from models import AE

import numpy as np

# %%
names = {
    0:"Force x",
    1:"Force y",
    2:"Force z",
    3:"Moment x",
    4:"Moment y",
    5:"Moment z",
    6:"Peg Position x",
    7:"Peg Position y",
    8:"Peg Position z",
    9:"Angle",
    10:"Time",
    11:"Counter",
}

# data = []
# sides=sides_200

# for i in range(len(sides[0])):
#     k=0
#     samples=[]
    
#     for j in range(15853):
#         samples.append(sides[k][i])
#         k+=100
        
#     trace0 = go.Scatter(
#         x=np.linspace(0, len(samples)-1, num=len(samples), endpoint=True),
#         y=samples,
#         mode='lines+markers',
#         name=names[i],
#         hoverinfo='name',
        
#         marker=dict(
#                 size=3.5,
#         ),
#         line=dict(
#             shape='linear',
# #             color=colors[i],
#              width=0.4,
#         )
#     )
#     data.append(trace0)

# layout = dict(
#     legend=dict(
#         y=0.5,
#         traceorder='reversed',
#         font=dict(
#             size=16
#         )
#     )
# )

# fig = go.Figure(data=data, layout=layout)


# fig = dict(data=data, layout=layout)
# plotly.offline.init_notebook_mode()
# plotly.offline.iplot(fig)


# # py.iplot(fig, filename='force_torque_dataset_sides_200_all')

# %% [markdown]
# ## Plot the original signals

# %%
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt

cmap=plt.cm.get_cmap(plt.cm.viridis,143)


# plt.rcParams['font.size'] = 11.
# plt.rcParams['font.family'] = 'Comic Sans MS'
# plt.rcParams['axes.labelsize'] = 15.
# plt.rcParams['xtick.labelsize'] = 10.
# plt.rcParams['ytick.labelsize'] = 10.

plt.figure(figsize=(30,10))



sides = sides_3
print(len(sides))

Force_x = sides[:,0] 
Force_y = sides[:,1]
Force_z = sides[:,2]
Moment_x = sides[:,3]
Moment_y = sides[:,4]
Moment_z = sides[:,5]
Peg_Position_x = sides[:,6]
Peg_Position_y = sides[:,7]
Peg_Position_z = sides[:,8]
Angle = sides[:,9]
Time = sides[:,10]
Counter = sides[:,11]


# plt.plot(Time, Force_x, marker='s', linestyle='-', markersize=2, linewidth=1, label='Force_x')
# plt.plot(Time, Force_y, marker='o', linestyle='-', markersize=2, linewidth=1, label='Force_y')
# plt.plot(Time, Force_z, marker='o', linestyle='-', markersize=2, linewidth=1, label='Force_z')

# plt.plot(Time, Moment_x, marker='o, linestyle='-', label='Moment_x')
# plt.plot(Time, Moment_y, marker='o, linestyle='-', label='Moment_y')
# plt.plot(Time, Moment_z, marker='o, linestyle='-', label='Moment_z')

# plt.plot(Time, Peg_Position_x, marker='o', linestyle='-', label='Peg_Position_x')
# plt.plot(Time, Peg_Position_y, marker='o', linestyle='-', label='Peg_Position_y')
# plt.plot(Time, Peg_Position_z, marker='o', linestyle='-', label='Peg_Position_z')

plt.plot(Time, Angle, marker='o', linestyle='-', label='Angle')
# plt.plot(Time, Counter, marker='o', linestyle='-', label='Counter')


plt.xlabel('Times')
plt.ylabel('Signals')
plt.title('3 Sileds force torque signals')
plt.legend(loc='lower right')
plt.show()
# Out:
# 1585353

# %%
print (len(sides_3))
print (len(sides_3[0]))
# Out:
# 1585353
# 12

# %%
# sides_3 = sides_3[:,0:10]

# %% [markdown]
# ## Normalize

# %%
def feature_normalize(data):
    mu = np.mean(data,axis=0)
    std = np.std(data,axis=0)
    return (data - mu)/std

def un_normalize(normalized_data, input_data):
    mu = np.mean(input_data,axis=0)
    std = np.std(input_data,axis=0)
    return normalized_data*std+mu
    

# sides_3 = feature_normalize(sides_3)

# %%
# for i in range(len(sides_3[1000])):
#     if i <= 9:
#         sides_3[:,i] = feature_normalize(sides_3[:,i])
#     else:
#         sides_3[:,i] = sides_3[:,i]
        

    
train_data = feature_normalize(sides_3)
test_data =feature_normalize(sides_3)

print(train_data.max(axis=0))
print(train_data.min(axis=0))
# Out:
# [ 1.61041529  1.60420085  6.98694537  1.58397099  5.45851616 14.18979856
#   2.0463434   5.16795321  7.59738043  8.87094703  1.73094382  1.73206426]
# [ -1.60663406  -1.57587557  -6.30031166  -1.58428425  -6.6635873
#   -5.66195959  -1.29488537 -20.90977217 -10.88038382 -14.44267477
#   -1.73095014  -1.73208833]

# %%
# number of subprocesses to use for data loading
num_workers = 4
# how many samples per batch to load
batch_size = 16
# percentage of training set to use as validation
valid_size = 0.2

# obtain training indices that will be used for validation
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# %%
import torch.utils.data
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, num_workers=num_workers,
                                           sampler=train_sampler)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, num_workers=num_workers,
                                           sampler=valid_sampler)

test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, num_workers=num_workers)
print (len(train_loader))
# Out:
# 79268

# %%
latent_size = 2

ae = AE(latent_size=latent_size).float()

optimizer = torch.optim.Adam(ae.parameters(), lr=0.001)

logs = defaultdict(list)
print(ae)

use_cuda = torch.cuda.is_available
if use_cuda:
    ae.cuda()
# Out:
# AE(
#   (encoder): Encoder(
#     (fc1): Linear(in_features=12, out_features=32, bias=True)
#     (fc2): Linear(in_features=32, out_features=8, bias=True)
#     (fc3): Linear(in_features=8, out_features=2, bias=True)
#   )
#   (decoder): Decoder(
#     (fc4): Linear(in_features=2, out_features=8, bias=True)
#     (fc5): Linear(in_features=8, out_features=32, bias=True)
#     (fc6): Linear(in_features=32, out_features=12, bias=True)
#   )
# )

# %%
# specify loss function
def loss_fn(recon_x, x):
    criterion = nn.MSELoss()
#     criterion = nn.CrossEntropyLoss()
#     x = x.long()
    loss = criterion(recon_x, x)
    return loss

# %%
epochs = 20
print_every = 100


for epoch in range(epochs):
    
    for iteration, d in enumerate(train_loader):
        if use_cuda:
            input_data = d.cuda().float()
        else:
            input_data = d.float()
        optimizer.zero_grad()
        recon_data = ae(input_data)
        loss = loss_fn(recon_data, input_data)
        loss.backward()
        optimizer.step()

        logs['loss'].append(loss.item())

        if iteration % print_every == 0 or iteration == len(train_loader)-1:
            correct = 0
            total = 0
            for valid in valid_loader:
                if use_cuda:
                    input_valid = valid.cuda().float()
                else:
                    input_valid = valid.float()

                output_valid = ae(input_valid)
                valid_loss = loss_fn(output_valid, input_valid)

                total +=1

                if valid_loss < 0.5:
                    correct += 1

            valid_acc = correct / total  
            
            print("Epoch {:02d}/{:02d} Batch {:04d}/{:d}, Train_loss {:9.4f}, Valid_accuary{:9.4f}".format(
                epoch, epochs, iteration, len(train_loader)-1, loss.item(), valid_acc))

    torch.save(ae, 'ae.pkl')  
        
    if loss < 0.01:
        break

            
# correct = 0
# total = 0
# for valid in valid_loader:
#     if use_cuda:
#         input_valid = valid.cuda().float()
#     else:
#         input_valid = valid.float()
        
#     output_valid = ae(input_valid)
#     valid_loss = loss_fn(output_valid, input_valid)
    
#     total +=1
    
#     if valid_loss < 0.02:
#         correct += 1
        
# valid_acc = correct / total
# Out:
# Epoch 00/20 Batch 0000/79267, Train_loss    0.7654, Valid_accuary   0.0000
# Epoch 00/20 Batch 0100/79267, Train_loss    1.1698, Valid_accuary   0.0000
# Epoch 00/20 Batch 0200/79267, Train_loss    0.6905, Valid_accuary   0.0000
# Epoch 00/20 Batch 0300/79267, Train_loss    1.0072, Valid_accuary   0.0000
# Epoch 00/20 Batch 0400/79267, Train_loss    0.7983, Valid_accuary   0.0000
# Epoch 00/20 Batch 0500/79267, Train_loss    0.8667, Valid_accuary   0.0000
# Epoch 00/20 Batch 0600/79267, Train_loss    0.7314, Valid_accuary   0.0000
# Epoch 00/20 Batch 0700/79267, Train_loss    0.7176, Valid_accuary   0.0000
# Epoch 00/20 Batch 0800/79267, Train_loss    1.0477, Valid_accuary   0.0000
# Epoch 00/20 Batch 0900/79267, Train_loss    0.8583, Valid_accuary   0.0000
# Epoch 00/20 Batch 1000/79267, Train_loss    0.9751, Valid_accuary   0.0000
# Epoch 00/20 Batch 1100/79267, Train_loss    0.9469, Valid_accuary   0.0000
# Epoch 00/20 Batch 1200/79267, Train_loss    0.8525, Valid_accuary   0.0000
# Epoch 00/20 Batch 1300/79267, Train_loss    1.2286, Valid_accuary   0.0000
# Epoch 00/20 Batch 1400/79267, Train_loss    0.9318, Valid_accuary   0.0000
# Epoch 00/20 Batch 1500/79267, Train_loss    0.7976, Valid_accuary   0.0000
# Epoch 00/20 Batch 1600/79267, Train_loss    0.8547, Valid_accuary   0.0000
# Epoch 00/20 Batch 1700/79267, Train_loss    0.7819, Valid_accuary   0.0000
# Epoch 00/20 Batch 1800/79267, Train_loss    0.9623, Valid_accuary   0.0000
# Epoch 00/20 Batch 1900/79267, Train_loss    1.0531, Valid_accuary   0.0000
# Epoch 00/20 Batch 2000/79267, Train_loss    0.8496, Valid_accuary   0.0000
# Epoch 00/20 Batch 2100/79267, Train_loss    0.7680, Valid_accuary   0.0000
# Epoch 00/20 Batch 2200/79267, Train_loss    0.8939, Valid_accuary   0.0000
# Epoch 00/20 Batch 2300/79267, Train_loss    0.9097, Valid_accuary   0.0001
# Epoch 00/20 Batch 2400/79267, Train_loss    0.7649, Valid_accuary   0.0000
# Epoch 00/20 Batch 2500/79267, Train_loss    0.7760, Valid_accuary   0.0000
# Epoch 00/20 Batch 2600/79267, Train_loss    0.8785, Valid_accuary   0.0000
# Epoch 00/20 Batch 2700/79267, Train_loss    0.7906, Valid_accuary   0.0000
# Epoch 00/20 Batch 2800/79267, Train_loss    0.6898, Valid_accuary   0.0000
# Epoch 00/20 Batch 2900/79267, Train_loss    0.7028, Valid_accuary   0.0000
# Epoch 00/20 Batch 3000/79267, Train_loss    0.7905, Valid_accuary   0.0000
# Epoch 00/20 Batch 3100/79267, Train_loss    0.9445, Valid_accuary   0.0000
# Epoch 00/20 Batch 3200/79267, Train_loss    0.8377, Valid_accuary   0.0001
# Epoch 00/20 Batch 3300/79267, Train_loss    0.9631, Valid_accuary   0.0000
# Epoch 00/20 Batch 3400/79267, Train_loss    0.8872, Valid_accuary   0.0000
# Epoch 00/20 Batch 3500/79267, Train_loss    0.8462, Valid_accuary   0.0000
# Epoch 00/20 Batch 3600/79267, Train_loss    0.7504, Valid_accuary   0.0000
# Epoch 00/20 Batch 3700/79267, Train_loss    0.9126, Valid_accuary   0.0000
# Epoch 00/20 Batch 3800/79267, Train_loss    0.6807, Valid_accuary   0.0000
# Epoch 00/20 Batch 3900/79267, Train_loss    1.3935, Valid_accuary   0.0000
# Epoch 00/20 Batch 4000/79267, Train_loss    0.9140, Valid_accuary   0.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-f277dc49a3a7> in <module>()
#      21             correct = 0
#      22             total = 0
# ---> 23             for valid in valid_loader:
#      24                 if use_cuda:
#      25                     input_valid = valid.cuda().float()
#
# ~/anaconda2/envs/clustering/lib/python3.5/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     580                 self.reorder_dict[idx] = batch
#     581                 continue
# --> 582             return self._process_next_batch(batch)
#     583
#     584     next = __next__  # Python 2 compatibility
#
# ~/anaconda2/envs/clustering/lib/python3.5/site-packages/torch/utils/data/dataloader.py in _process_next_batch(self, batch)
#     599     def _process_next_batch(self, batch):
#     600         self.rcvd_idx += 1
# --> 601         self._put_indices()
#     602         if isinstance(batch, _utils.ExceptionWrapper):
#     603             # make multiline KeyError msg readable by working around
#
# ~/anaconda2/envs/clustering/lib/python3.5/site-packages/torch/utils/data/dataloader.py in _put_indices(self)
#     589     def _put_indices(self):
#     590         assert self.batches_outstanding < 2 * self.num_workers
# --> 591         indices = next(self.sample_iter, None)
#     592         if indices is None:
#     593             return
#
# ~/anaconda2/envs/clustering/lib/python3.5/site-packages/torch/utils/data/sampler.py in __iter__(self)
#     170     def __iter__(self):
#     171         batch = []
# --> 172         for idx in self.sampler:
#     173             batch.append(idx)
#     174             if len(batch) == self.batch_size:
#
# ~/anaconda2/envs/clustering/lib/python3.5/site-packages/torch/utils/data/sampler.py in <genexpr>(.0)
#      94
#      95     def __iter__(self):
# ---> 96         return (self.indices[i] for i in torch.randperm(len(self.indices)))
#      97
#      98     def __len__(self):
#
# KeyboardInterrupt:

# %%
params = list(ae.named_parameters())
print(params)
# Out:
# [('encoder.fc1.weight', Parameter containing:
# tensor([[ 8.6174e-03, -1.0068e-01, -4.2744e-02,  1.9617e-01,  3.3556e-02,
#          -1.3730e-02,  3.6199e-02, -1.1249e-02, -8.2660e-03,  1.7836e-02,
#           2.5727e-01,  1.5501e-02],
#         [-1.5026e-03,  3.9488e-02,  6.2611e-05,  1.3502e-01, -2.2794e-02,
#          -5.3521e-03, -2.3264e-01,  5.6521e-01,  2.1472e-01, -6.8965e-02,
#          -1.8610e-01,  1.8613e-01],
#         [ 9.7095e-02,  4.7430e-01, -1.1564e-01, -1.8099e-01,  2.9765e-02,
#           2.5543e-02,  5.6717e-02,  4.7020e-02,  4.8671e-02,  6.5481e-01,
#           4.7808e-02,  2.7983e-01],
#         [ 8.7879e-02, -3.7234e-03,  8.1130e-01,  6.4384e-02, -1.3219e-01,
#           2.6435e-02, -4.1147e-01, -7.3628e-02, -4.0421e-02,  2.9390e-02,
#          -2.8016e-01, -1.1634e-01],
#         [-2.0416e-02, -3.4511e-02,  2.0690e-02,  2.0821e-01, -1.5113e-03,
#          -7.5275e-03, -2.2174e-01,  7.3314e-01,  1.0703e+00, -4.8726e-02,
#          -9.6697e-02,  3.1815e-01],
#         [ 2.2784e-02,  4.8524e-01, -2.5060e-01,  9.7587e-01,  9.1769e-02,
#          -6.5714e-02,  1.8118e-01,  2.6892e-02, -3.4040e-02,  3.3424e-02,
#           1.0437e+00,  4.9979e-02],
#         [-4.5540e-02, -1.4964e-01,  5.4571e-01, -3.0535e-02,  1.0048e-01,
#          -1.3537e-01, -1.6188e-01, -6.6813e-02, -1.3073e-01,  6.4171e-02,
#           1.0632e-01, -2.2806e-01],
#         [ 1.0484e-02, -6.0129e-02,  2.3989e-01, -2.8397e-02,  3.4367e-03,
#          -6.7471e-02, -4.9172e-01, -6.6897e-03, -9.7355e-02,  9.8438e-01,
#          -9.7130e-03, -4.8893e-01],
#         [ 2.8967e-02,  1.2328e-02,  5.4246e-01,  8.6199e-02,  6.7718e-02,
#          -7.1703e-02, -2.3484e-01, -7.2165e-02, -1.3700e-02, -2.0146e-02,
#           6.5837e-02, -6.6689e-02],
#         [ 2.6077e-01,  2.2465e-02,  5.5916e-01,  3.5258e-02, -1.6003e-02,
#          -1.5013e-01, -5.9839e-01, -1.9622e-01, -3.9374e-01,  8.4390e-01,
#          -9.6246e-03, -6.3063e-01],
#         [ 4.8288e-03,  1.4818e-03,  1.3550e-03,  1.6490e-01,  1.9195e-02,
#          -8.6962e-02,  9.8477e-02,  7.8324e-01,  1.6067e-01,  6.4340e-02,
#           1.8574e-02,  6.4406e-03, -4.3048e-02,  5.0273e-01,  8.7801e-02,
#          -1.1694e-01,  1.2861e-01,  1.0711e+00, -1.0383e-01, -2.0870e-02,
#          -7.0158e-02,  4.2858e-02,  1.5368e-03, -7.7740e-02,  6.0096e-02,
#           2.2706e-01,  2.3610e-02,  7.4210e-01,  5.6849e-02, -1.7163e-02,
#           1.9651e-01, -3.4635e-01],
#         [-2.3346e-02, -1.9163e-01,  2.2822e-02, -2.1726e+00, -8.2467e-02,
#           1.0453e-02, -1.3982e+00, -3.9174e-02,  1.2235e-01, -5.4090e+00,
#          -2.1995e-01,  1.6418e-01, -3.1603e-02,  6.4579e-03, -1.6512e-01,
#          -1.6341e-02,  1.2253e-02, -3.4418e-02, -1.2538e-01,  1.2023e-01,
#           2.0223e-02,  1.8259e-01,  1.4286e-01, -6.8081e-02, -1.6287e-01,
#          -3.6326e+00, -1.0573e+00, -3.1147e-01,  4.7414e-02, -7.5562e+00,
#           1.0136e-01,  6.0924e-03]], device='cuda:0', requires_grad=True)), ('encoder.fc2.bias', Parameter containing:
# tensor([-0.3119,  0.4886,  0.1951,  0.1126,  0.8384,  0.0752,  0.3991,  0.1870],
#        device='cuda:0', requires_grad=True)), ('encoder.fc3.weight', Parameter containing:
# tensor([[-0.0826,  0.0726,  0.9175,  1.5759,  0.1236,  2.2787, -0.1899, -0.3910],
#         [-0.4518,  0.3791,  0.2769, -0.1952,  0.4715,  0.3638,  0.0739, -2.1036]],
#        device='cuda:0', requires_grad=True)), ('encoder.fc3.bias', Parameter containing:
# tensor([0.4358, 0.7334], device='cuda:0', requires_grad=True)), ('decoder.fc4.weight', Parameter containing:
# tensor([[-1.4522,  0.2888],
#         [-0.0165,  0.6180],
#         [ 0.0262, -0.6610],
#         [-0.2424, -0.3480],
#         [ 0.2042, -0.4701],
#         [-0.4649,  0.8981],
#         [ 0.0819,  0.5174],
#         [-0.9502,  0.1064]], device='cuda:0', requires_grad=True)), ('decoder.fc4.bias', Parameter containing:
# tensor([ 0.6162, -0.0134,  1.0423, -0.6778,  0.2371, -0.3025, -0.2934,  0.9633],
#        device='cuda:0', requires_grad=True)), ('decoder.fc5.weight', Parameter containing:
# tensor([[ 1.1201e+00, -9.0994e-02,  7.7574e-01, -9.5870e-02,  3.0605e-01,
#           1.1584e-01, -3.8354e-01,  6.8064e-01],
#         [-6.7834e-01,  2.7226e-01, -2.3620e-01, -8.7562e-02, -4.1783e-02,
#           1.0572e-01,  1.5195e-01,  6.7610e-01],
#         [ 5.9345e-02,  3.1188e-01,  1.7784e-01,  1.3367e-01, -8.3095e-01,
#           7.5645e-01, -9.5874e-01, -3.2150e-01],
#         [-9.7579e-02,  4.1908e-01, -2.0507e-03,  1.2365e-04, -1.0479e+00,
#           4.0848e-01,  2.1246e-01,  7.8910e-01],
#         [ 5.9621e-02,  2.6102e-01, -6.5711e-01,  2.8983e-02,  9.0685e-02,
#           7.7726e-01,  7.3645e-02,  3.0604e-01],
#         [-1.1816e+00, -3.4309e-01,  7.4231e-01, -2.9757e-01, -9.8319e-02,
#         [ 1.3569e-01, -3.3477e-01, -9.4309e-02, -1.6046e-01, -2.9871e-01,
#          -1.0360e-01, -3.6124e-02,  2.5560e-01],
#         [-2.3662e-01, -2.2143e-01,  8.9462e-02,  2.3866e-01, -3.0412e-01,
#           2.3634e-01, -2.2203e-01, -2.7521e-01],
#         [-9.1717e-01,  2.0482e-02,  9.3544e-01, -3.1455e-01, -1.5848e+00,
#          -6.7785e-01,  4.2238e-01,  8.5923e-02],
#         [-3.1192e-01, -2.2108e-01, -4.2680e-01,  1.1683e-01,  1.2449e-02,
#           2.4571e-01, -6.8616e-02,  2.6844e-01],
#         [ 2.1171e-01,  1.8347e-01, -3.6916e-01,  9.8706e-02, -1.1107e-01,
#          -1.5044e+00,  5.5040e-01, -1.4715e+00],
#         [ 3.5308e-01, -2.6648e-01,  3.0509e-01, -2.4303e-01, -1.4966e-01,
#          -1.7545e-01, -1.9261e-01, -2.4790e-01],
#         [-1.3174e+00,  1.8301e-01,  2.0693e-01,  1.9115e-01, -2.1134e-02,
#           7.7150e-02, -9.4859e-02, -6.3913e-01]], device='cuda:0',
#        requires_grad=True)), ('decoder.fc5.bias', Parameter containing:
# tensor([ 0.5767, -0.1678,  0.2840, -0.2397, -0.5587,  0.1596,  0.6264,  0.0818,
#          0.5198, -0.0454,  0.6326, -0.1911,  0.6012,  0.4262,  0.6109, -0.7071,
#         -0.3028,  0.3235,  0.3288, -0.0105, -0.4341, -0.1280,  0.5099,  0.3045,
#          0.1719, -0.2765, -0.1532, -0.1478, -0.1795,  0.5154, -0.3362,  0.5084],
#        device='cuda:0', requires_grad=True)), ('decoder.fc6.weight', Parameter containing:
# tensor([[-5.8941e-02, -2.6908e-01,  4.3939e-02, -1.2959e-01,  1.4273e-03,
#          -6.8332e-03,  4.1056e-02, -7.8286e-02,  7.5330e-02,  7.6389e-02,
#           8.7272e-02, -2.2376e-02, -1.1694e-01,  2.8070e-02, -4.2864e-03,
#          -1.7171e-01,  2.3603e-02, -6.9955e-02, -7.9963e-02, -1.5987e-01,
#           9.0947e-02,  4.0594e-02, -4.5208e-02, -7.7763e-02, -3.1872e-02,
#          -1.2678e-01,  5.5974e-02, -1.2492e-01,  2.6122e-02, -3.4376e-02,
#           2.6224e-02, -1.7774e-01],
#         [-2.6353e-01,  3.7194e-01,  9.8467e-03,  2.1325e-01, -1.1734e-01,
#           4.6661e-01, -1.3425e-01, -4.0175e-01,  2.8919e-01,  1.4284e-01,
#          -8.7065e-01,  7.8714e-02,  9.4518e-01,  1.8508e-01, -2.9537e+00,
#          -7.6223e-01, -1.2686e-01,  2.1669e-01,  9.4270e-01,  1.4423e-02,
#          -6.2202e-03, -1.0757e+00, -1.9295e+00, -6.6296e-01,  8.4040e-01,
#           2.4039e-02,  9.9772e-02, -1.8337e-02,  8.4385e-02,  6.9071e-02,
#           6.8676e-02, -6.5387e-01],
#         [-1.6308e+00, -4.0816e-02,  1.7912e-01,  1.0602e-01, -2.6158e-02,
#          -9.1321e-01, -2.3821e+00,  6.3470e-02, -4.0602e+00,  1.4675e-01,
#          -4.9121e-01, -1.1487e-01,  5.6018e-02, -6.6483e-01,  3.7231e-01,
#          -7.9058e-01,  1.2869e+00,  5.8792e-02,  3.8702e-03, -3.0462e-01,
#          -6.7768e-02,  7.7066e-02, -6.0546e-02, -1.7199e-01,  4.9729e-01,
#           1.6742e-02,  1.6772e-01],
#         [ 1.2649e-01, -2.9965e-01, -3.5743e-01, -8.4042e-01, -3.3393e-01,
#          -1.2707e-01,  1.5565e-01, -7.4472e-02,  1.3910e-01,  7.7913e-02,
#          -6.4999e-01,  1.0648e-02,  1.6800e-01,  2.9713e-01,  7.0868e-03,
#           1.9258e-01, -7.6021e-02, -1.6911e-01,  3.9136e-01,  1.3283e-01,
#           1.2254e-01, -1.5974e-01,  2.7084e-01,  1.1299e-01, -3.6375e-02,
#          -1.5829e-01, -1.3137e-01, -8.3674e-02, -1.7604e-01,  4.2793e-01,
#          -8.6366e-04,  4.2399e-02],
#         [ 6.6568e-02,  1.9727e-01,  3.2654e-01,  3.4610e-01,  3.6720e-01,
#           3.1521e-01, -7.2603e-01,  1.6329e-01, -4.6435e+00,  3.2637e-03,
#           2.0737e-03, -6.5906e-02, -3.7168e-01, -2.4563e+00, -1.8935e-01,
#           2.1627e-01,  1.5948e-01,  3.1342e-01, -9.8464e-02, -2.3967e-02,
#          -5.3007e-01, -3.4853e-01, -6.0887e-01, -5.8105e-02,  3.9798e-01,
#          -7.5289e-02, -1.1781e-01,  7.6615e-01, -2.9934e-02, -7.0534e-01,
#          -1.7128e-01, -3.1740e-04],
#         [ 4.3977e-01,  1.1399e-01, -1.9980e-01,  7.5822e-02, -1.0972e-01,
#          -1.2648e-01,  2.8322e-01, -3.5619e+00, -1.2647e-01, -1.3897e-01,
#          -2.5966e+00,  9.6858e-03,  1.0674e+00, -1.9532e-01, -3.3044e+00,
#           7.1155e-02, -5.5058e-03,  2.4338e-02, -3.8428e-02, -4.3270e-02,
#           1.3813e-01, -5.4877e-02, -5.6065e-01, -3.5580e+00, -1.5970e-01,
#           8.1691e-02,  5.4809e-02, -4.9774e-02,  5.1639e-02, -5.7702e-03,
#          -5.5575e-02, -2.5770e+00],
#         [ 3.2079e-01,  1.1547e-01,  1.0203e-01,  1.3133e-01,  1.8266e-01,
#           2.7871e-01,  4.2434e-01,  1.2944e-01, -1.3225e+00, -1.3587e-01,
#           8.7090e-01, -1.4976e-01,  1.7780e-02, -5.2144e-01, -4.7191e-02,
#           2.4326e-02, -1.3748e-01,  2.2280e-01, -5.4932e-01,  1.5675e-01,
#          -1.5053e+00, -4.9401e-01,  1.5173e-01,  1.0584e-01,  2.8622e-01,
#          -1.0383e-01,  8.5421e-02, -1.0848e+00, -2.0685e-01,  5.8968e-01,
#          -1.3431e-01, -5.7682e-02]], device='cuda:0', requires_grad=True)), ('decoder.fc6.bias', Parameter containing:
# tensor([-0.2041,  0.6813,  0.1727, -0.0935, -0.2462, -0.1619,  0.1246,  0.3383,
#         -0.2511,  0.0806,  0.2901,  0.2970], device='cuda:0',
#        requires_grad=True))]

# %%
torch.save(ae, 'ae_1_epoch_8_8.pkl')

# %%
import torch
ae = torch.load('ae.pkl')
print(ae)

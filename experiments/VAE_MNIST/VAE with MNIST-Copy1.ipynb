# %%
import os
import time
import torch
import argparse
import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
from torchvision import transforms
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader
from collections import defaultdict
import torch.multiprocessing as mp
import torch.utils.data
import torch
import numpy as np
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler
import torch.nn as nn

from models import VAE


device = torch.device('cpu')

# convert data to torch.FloatTensor
transform = transforms.ToTensor()

# load the training and test datasets
# train_data = datasets.MNIST(root='data', train=True,
#                                    download=True, transform=transform)
# test_data = datasets.MNIST(root='data', train=False,
#                                   download=True, transform=transform)

# data_loader = DataLoader(
#     dataset=dataset, batch_size=args.batch_size, shuffle=True)
# print(len(train_data))

dataset = MNIST(
    root='data', train=True, transform=transforms.ToTensor(),
    download=True)


print(type(dataset))

# for images in t
# images = images.view(images.size(0), -1)
# Out:
# <class 'torchvision.datasets.mnist.MNIST'>

# %%
# Create training and test dataloaders

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 32


valid_size = 0.2

# obtain training indices that will be used for validation
num_train = len(dataset)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# prepare data loaders
# train_loader = torch.utils.data.DataLoader(train_data,batch_size=batch_size,num_workers=num_workers,sampler=train_sampler)
# valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, num_workers=num_workers,sampler=valid_sampler)
# test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, num_workers=num_workers)

data_loader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True)
train_loader = data_loader
valid_loader = data_loader
test_loader = data_loader
# train_loader = torch.utils.data.DataLoader(data_loader,batch_size=batch_size,num_workers=num_workers,sampler=train_sampler)
# valid_loader = torch.utils.data.DataLoader(data_loader, batch_size=batch_size, num_workers=num_workers,sampler=valid_sampler)
# test_loader = torch.utils.data.DataLoader(data_loader, batch_size=batch_size, num_workers=num_workers)

# print(len(train_loader))
# print(len(valid_loader))
# print(len(test_loader))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
    
# obtain one batch of training images
dataiter = iter(data_loader)
images, labels = dataiter.next()
images = images.numpy()

# get one image from the batch
img = np.squeeze(images[0])

fig = plt.figure(figsize = (5,5)) 
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')

# %% [markdown]
# Loss function
# --------------------

# %%
def loss_fn(recon_x, x, mean, log_var):
#     criterion = nn.BCEWithLogitsLoss(reduction='sum')
#     BCE = criterion(recon_x, x) / len(x)

#     recon_x = torch.clamp(recon_x, 0, 1)
#     x = torch.clamp(x, 0, 1) 
    
    BCE = torch.nn.functional.binary_cross_entropy(recon_x.view(-1, 28*28), x.view(-1, 28*28), reduction='sum')
    KLD = -0.5 * torch.sum(1 + log_var - mean.pow(2) - log_var.exp())
    # elbo = recon_loss + self.beta * D_kl
    elbo = (BCE + KLD)/ x.size(0)
    return elbo

# %%
seed = 0
epochs = 20
latent_size = 2
num_processes = 2
learning_rate = 0.001
print_every = 100
encoder_layer_sizes=[784, 256]
decoder_layer_sizes=[256, 784]

vae = VAE(latent_size=latent_size).float().to(device)

# vae = VAE(
#     encoder_layer_sizes=encoder_layer_sizes,
#     latent_size=latent_size,
#     decoder_layer_sizes=decoder_layer_sizes).to(device)

use_cuda = torch.cuda.is_available
if use_cuda:
    vae.to(device)

logs = defaultdict(list)
    
epochs = epochs
for epoch in range(epochs):
    lr_havel = learning_rate
    optimizer = torch.optim.Adam(vae.parameters(), lr=lr_havel)
    
    for iteration, data in enumerate(train_loader):
        images, _ = data
        images = images.view(images.size(0), -1)
        if use_cuda:
            images = images.to(device).float()
        else:
            images = images.float()

        optimizer.zero_grad()
        recon_x, mean, log_var, z = vae(images)
        elbo = loss_fn(recon_x, images, mean, log_var)
        loss = elbo
        loss.backward()
        optimizer.step()

        logs['loss'].append(loss.item())

        if iteration % print_every == 0 or iteration == len(train_loader)-1:
            valid_correct = 0
            valid_total = 0
            test_correct = 0
            test_total = 0

            for valid_data in valid_loader:
                valid, _ = valid_data
                valid = images.view(valid.size(0), -1)
                if use_cuda:
                    input_valid = valid.to(device).float()
                else:
                    input_valid = valid.float()
                valid_recon_x, valid_mean, valid_log_var, valid_z = vae(input_valid)
                valid_elbo = loss_fn(valid_recon_x, input_valid, valid_mean, valid_log_var)
                criterion = nn.MSELoss()
                valid_loss = criterion(valid_recon_x, input_valid)
                logs['valid_elbo'].append(valid_elbo.item())
                logs['valid_loss'].append(valid_loss.item())
                valid_total +=1
                if valid_loss < 0.05:
                    valid_correct += 1
            valid_acc = valid_correct / valid_total  
            print("Epoch {:02d}/{:02d} Batch {:04d}/{:d} |Train_ELBO {:5f} |Valid_ELBO{:5f} |Valid_loss{:5f} |Valid_accuary{:5f} |Leaarning_rate{:5f}".format(
                epoch, epochs, iteration, len(train_loader)-1, loss.item(), valid_elbo.item(), valid_loss.item(), valid_acc, lr_havel))

    lr_havel = lr_havel*0.9
    torch.save(vae, 'vae_mnist_binary_cross_entropy.pkl')
# Out:
# Epoch 00/20 Batch 0000/1874 |Train_ELBO 563.485413 |Valid_ELBO561.567444 |Valid_loss0.240947 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 00/20 Batch 0100/1874 |Train_ELBO 278.254242 |Valid_ELBO281.616638 |Valid_loss0.083027 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 00/20 Batch 0200/1874 |Train_ELBO 187.732559 |Valid_ELBO186.608597 |Valid_loss0.053928 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 00/20 Batch 0300/1874 |Train_ELBO 177.836121 |Valid_ELBO182.338303 |Valid_loss0.055491 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 00/20 Batch 0400/1874 |Train_ELBO 179.204987 |Valid_ELBO179.518860 |Valid_loss0.053963 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 00/20 Batch 0500/1874 |Train_ELBO 180.300247 |Valid_ELBO180.966599 |Valid_loss0.054918 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 00/20 Batch 0600/1874 |Train_ELBO 173.458969 |Valid_ELBO172.635803 |Valid_loss0.051473 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 00/20 Batch 0700/1874 |Train_ELBO 173.921326 |Valid_ELBO169.546677 |Valid_loss0.050982 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 00/20 Batch 0800/1874 |Train_ELBO 191.032562 |Valid_ELBO190.358566 |Valid_loss0.057043 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 00/20 Batch 0900/1874 |Train_ELBO 189.108017 |Valid_ELBO191.494583 |Valid_loss0.059891 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 00/20 Batch 1000/1874 |Train_ELBO 193.734131 |Valid_ELBO199.238525 |Valid_loss0.061720 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 00/20 Batch 1100/1874 |Train_ELBO 190.352463 |Valid_ELBO188.717178 |Valid_loss0.057587 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 00/20 Batch 1200/1874 |Train_ELBO 179.192673 |Valid_ELBO183.362030 |Valid_loss0.056198 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 00/20 Batch 1300/1874 |Train_ELBO 162.873856 |Valid_ELBO161.426956 |Valid_loss0.047628 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 00/20 Batch 1400/1874 |Train_ELBO 175.723297 |Valid_ELBO172.094818 |Valid_loss0.051083 |Valid_accuary0.000533 |Leaarning_rate0.001000
# Epoch 00/20 Batch 1500/1874 |Train_ELBO 172.811966 |Valid_ELBO174.308746 |Valid_loss0.051227 |Valid_accuary0.008533 |Leaarning_rate0.001000
# Epoch 00/20 Batch 1600/1874 |Train_ELBO 166.428406 |Valid_ELBO165.754822 |Valid_loss0.049173 |Valid_accuary0.984533 |Leaarning_rate0.001000
# Epoch 00/20 Batch 1700/1874 |Train_ELBO 176.058517 |Valid_ELBO176.783737 |Valid_loss0.053402 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 00/20 Batch 1800/1874 |Train_ELBO 178.310501 |Valid_ELBO177.147278 |Valid_loss0.051959 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 00/20 Batch 1874/1874 |Train_ELBO 162.694061 |Valid_ELBO162.727600 |Valid_loss0.047582 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 01/20 Batch 0000/1874 |Train_ELBO 159.491364 |Valid_ELBO157.015137 |Valid_loss0.045827 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 01/20 Batch 0100/1874 |Train_ELBO 178.160812 |Valid_ELBO179.735245 |Valid_loss0.052732 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 01/20 Batch 0200/1874 |Train_ELBO 183.027466 |Valid_ELBO184.816833 |Valid_loss0.055933 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 01/20 Batch 0300/1874 |Train_ELBO 173.575073 |Valid_ELBO173.658936 |Valid_loss0.051621 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 01/20 Batch 0400/1874 |Train_ELBO 179.864044 |Valid_ELBO181.419189 |Valid_loss0.054865 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 01/20 Batch 0500/1874 |Train_ELBO 165.803650 |Valid_ELBO166.733887 |Valid_loss0.048713 |Valid_accuary0.982400 |Leaarning_rate0.001000
# Epoch 01/20 Batch 0600/1874 |Train_ELBO 178.908981 |Valid_ELBO177.550552 |Valid_loss0.053481 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 01/20 Batch 0700/1874 |Train_ELBO 170.882721 |Valid_ELBO167.194290 |Valid_loss0.048454 |Valid_accuary0.899733 |Leaarning_rate0.001000
# Epoch 01/20 Batch 0800/1874 |Train_ELBO 163.882156 |Valid_ELBO163.681961 |Valid_loss0.047879 |Valid_accuary0.997333 |Leaarning_rate0.001000
# Epoch 01/20 Batch 0900/1874 |Train_ELBO 184.338104 |Valid_ELBO186.633774 |Valid_loss0.058339 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 01/20 Batch 1000/1874 |Train_ELBO 181.220062 |Valid_ELBO181.176193 |Valid_loss0.054195 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 01/20 Batch 1100/1874 |Train_ELBO 171.513199 |Valid_ELBO173.928757 |Valid_loss0.052126 |Valid_accuary0.012800 |Leaarning_rate0.001000
# Epoch 01/20 Batch 1200/1874 |Train_ELBO 182.141937 |Valid_ELBO184.956665 |Valid_loss0.056296 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 01/20 Batch 1300/1874 |Train_ELBO 164.207489 |Valid_ELBO167.423737 |Valid_loss0.049874 |Valid_accuary0.716800 |Leaarning_rate0.001000
# Epoch 01/20 Batch 1400/1874 |Train_ELBO 178.563904 |Valid_ELBO179.887711 |Valid_loss0.054111 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 01/20 Batch 1500/1874 |Train_ELBO 171.030228 |Valid_ELBO171.272873 |Valid_loss0.051230 |Valid_accuary0.001600 |Leaarning_rate0.001000
# Epoch 01/20 Batch 1600/1874 |Train_ELBO 186.835693 |Valid_ELBO181.941925 |Valid_loss0.055313 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 01/20 Batch 1700/1874 |Train_ELBO 169.148514 |Valid_ELBO169.861404 |Valid_loss0.050591 |Valid_accuary0.318400 |Leaarning_rate0.001000
# Epoch 01/20 Batch 1800/1874 |Train_ELBO 184.039749 |Valid_ELBO188.612198 |Valid_loss0.058608 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 01/20 Batch 1874/1874 |Train_ELBO 169.005829 |Valid_ELBO167.240524 |Valid_loss0.049346 |Valid_accuary0.931733 |Leaarning_rate0.001000
# Epoch 02/20 Batch 0000/1874 |Train_ELBO 165.165192 |Valid_ELBO163.178635 |Valid_loss0.047534 |Valid_accuary0.997333 |Leaarning_rate0.001000
# Epoch 02/20 Batch 0100/1874 |Train_ELBO 160.258408 |Valid_ELBO162.485001 |Valid_loss0.048057 |Valid_accuary0.997333 |Leaarning_rate0.001000
# Epoch 02/20 Batch 0200/1874 |Train_ELBO 166.440460 |Valid_ELBO165.551834 |Valid_loss0.049749 |Valid_accuary0.333333 |Leaarning_rate0.001000
# Epoch 02/20 Batch 0300/1874 |Train_ELBO 172.783569 |Valid_ELBO175.065872 |Valid_loss0.053045 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 02/20 Batch 0400/1874 |Train_ELBO 157.868469 |Valid_ELBO156.011826 |Valid_loss0.044530 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 02/20 Batch 0500/1874 |Train_ELBO 176.056244 |Valid_ELBO173.798157 |Valid_loss0.051697 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 02/20 Batch 0600/1874 |Train_ELBO 181.545868 |Valid_ELBO180.555878 |Valid_loss0.054032 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 02/20 Batch 0700/1874 |Train_ELBO 176.164963 |Valid_ELBO177.469193 |Valid_loss0.054128 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 02/20 Batch 0800/1874 |Train_ELBO 168.517349 |Valid_ELBO165.815384 |Valid_loss0.048665 |Valid_accuary0.956267 |Leaarning_rate0.001000
# Epoch 02/20 Batch 0900/1874 |Train_ELBO 162.404694 |Valid_ELBO161.193161 |Valid_loss0.046423 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 02/20 Batch 1000/1874 |Train_ELBO 170.171280 |Valid_ELBO170.320938 |Valid_loss0.049729 |Valid_accuary0.687467 |Leaarning_rate0.001000
# Epoch 02/20 Batch 1100/1874 |Train_ELBO 165.324936 |Valid_ELBO167.085602 |Valid_loss0.051029 |Valid_accuary0.149867 |Leaarning_rate0.001000
# Epoch 02/20 Batch 1200/1874 |Train_ELBO 178.646164 |Valid_ELBO178.392960 |Valid_loss0.052586 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 02/20 Batch 1300/1874 |Train_ELBO 169.125580 |Valid_ELBO169.361038 |Valid_loss0.050226 |Valid_accuary0.365867 |Leaarning_rate0.001000
# Epoch 02/20 Batch 1400/1874 |Train_ELBO 169.572128 |Valid_ELBO167.646347 |Valid_loss0.049491 |Valid_accuary0.677867 |Leaarning_rate0.001000
# Epoch 02/20 Batch 1500/1874 |Train_ELBO 189.151062 |Valid_ELBO191.961166 |Valid_loss0.057927 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 02/20 Batch 1600/1874 |Train_ELBO 172.968124 |Valid_ELBO174.599564 |Valid_loss0.052544 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 02/20 Batch 1700/1874 |Train_ELBO 174.462830 |Valid_ELBO174.553802 |Valid_loss0.051668 |Valid_accuary0.012267 |Leaarning_rate0.001000
# Epoch 02/20 Batch 1800/1874 |Train_ELBO 190.304443 |Valid_ELBO193.295105 |Valid_loss0.058689 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 02/20 Batch 1874/1874 |Train_ELBO 173.018951 |Valid_ELBO169.622391 |Valid_loss0.051489 |Valid_accuary0.166400 |Leaarning_rate0.001000
# Epoch 03/20 Batch 0000/1874 |Train_ELBO 164.787827 |Valid_ELBO165.990646 |Valid_loss0.049038 |Valid_accuary0.997333 |Leaarning_rate0.001000
# Epoch 03/20 Batch 0100/1874 |Train_ELBO 174.289032 |Valid_ELBO173.911163 |Valid_loss0.052054 |Valid_accuary0.000533 |Leaarning_rate0.001000
# Epoch 03/20 Batch 0200/1874 |Train_ELBO 161.885727 |Valid_ELBO158.532181 |Valid_loss0.046411 |Valid_accuary0.999467 |Leaarning_rate0.001000
# Epoch 03/20 Batch 0300/1874 |Train_ELBO 166.085083 |Valid_ELBO164.684769 |Valid_loss0.047767 |Valid_accuary0.996267 |Leaarning_rate0.001000
# Epoch 03/20 Batch 0400/1874 |Train_ELBO 174.619293 |Valid_ELBO176.423798 |Valid_loss0.053598 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 03/20 Batch 0500/1874 |Train_ELBO 161.138046 |Valid_ELBO159.798340 |Valid_loss0.046180 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 03/20 Batch 0600/1874 |Train_ELBO 168.197495 |Valid_ELBO170.361603 |Valid_loss0.049916 |Valid_accuary0.658133 |Leaarning_rate0.001000
# Epoch 03/20 Batch 0700/1874 |Train_ELBO 184.607132 |Valid_ELBO185.939850 |Valid_loss0.056922 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 03/20 Batch 0800/1874 |Train_ELBO 174.971512 |Valid_ELBO173.992065 |Valid_loss0.052815 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 03/20 Batch 0900/1874 |Train_ELBO 167.993652 |Valid_ELBO168.382462 |Valid_loss0.049698 |Valid_accuary0.758400 |Leaarning_rate0.001000
# Epoch 03/20 Batch 1000/1874 |Train_ELBO 168.446335 |Valid_ELBO167.406631 |Valid_loss0.049627 |Valid_accuary0.797333 |Leaarning_rate0.001000
# Epoch 03/20 Batch 1100/1874 |Train_ELBO 188.308899 |Valid_ELBO185.572388 |Valid_loss0.055596 |Valid_accuary0.000000 |Leaarning_rate0.001000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-4ba8f7a576f4> in <module>()
#      57                     input_valid = valid.float()
#      58                 valid_recon_x, valid_mean, valid_log_var, valid_z = vae(input_valid)
# ---> 59                 valid_elbo = loss_fn(valid_recon_x, input_valid, valid_mean, valid_log_var)
#      60                 criterion = nn.MSELoss()
#      61                 valid_loss = criterion(valid_recon_x, input_valid)
#
# <ipython-input-4-59eb566643b9> in loss_fn(recon_x, x, mean, log_var)
#       9     KLD = -0.5 * torch.sum(1 + log_var - mean.pow(2) - log_var.exp())
#      10     # elbo = recon_loss + self.beta * D_kl
# ---> 11     elbo = (BCE + KLD)/ x.size(0)
#      12     return elbo
#
# KeyboardInterrupt:

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()

# images = images.to(device)
images_flatten = images.view(images.size(0), -1).to(device)
# get sample outputs
test_recon_x, test_mean, test_log_var, test_z = vae(images_flatten)
# prep images for display
images = images.numpy()

# output is resized into a batch of images
output = test_recon_x
output = output.view(batch_size, 1, 28, 28)
# use detach when it's an output that requires_grad
output = output.cpu().detach().numpy()

# plot the first ten input images and then reconstructed images
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(25,4))

# input images on top row, reconstructions on bottom
for images, row in zip([images, output], axes):
    for img, ax in zip(images, row):
        ax.imshow(np.squeeze(img), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

# %%
z = torch.randn([batch_size, 2]).cpu()

print(z)

# recon_x = vae.decoder(z, c=None)
recon_x = vae.decoder(z)

plt.figure()
plt.figure(figsize=(5, 20))
for p in range(batch_size):
    plt.subplot(10, 2, p+1)
    plt.imshow(recon_x[p].view(28, 28).data.numpy())
    plt.axis('off')
# Out:
# tensor([[-0.4404, -0.4449],
#         [ 0.3919,  0.4602],
#         [-0.0053, -0.8179],
#         [ 1.1413,  0.6337],
#         [-0.9777, -0.1770],
#         [-0.7118,  0.3304],
#         [-1.1535, -1.3692],
#         [-1.2721,  0.1877],
#         [ 0.0792,  2.0701],
#         [ 0.1912, -0.1739],
#         [ 1.1880,  0.7759],
#         [-0.9598, -1.0343],
#         [-0.0665,  1.2942],
#         [-1.1382,  0.0654],
#         [-1.6429,  0.0877],
#         [ 0.5832, -0.8605],
#         [-1.3316,  0.8834],
#         [-0.4314, -0.0312],
#         [ 1.5887,  0.7461],
#         [ 0.2431,  1.2840],
#         [-0.4985, -1.0102],
#         [-1.3089,  0.2515],
#         [ 1.2832, -1.9842],
#         [-1.6596, -0.9967],
#         [-1.4178, -1.1339],
#         [ 0.5517,  0.0569],
#         [-0.6152, -0.8715],
#         [-1.3411,  0.1267],
#         [-2.0589, -0.0931],
#         [ 1.0465, -0.2699],
#         [-2.0395,  0.0475],
#         [-0.1899, -0.2020]])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-354c599dce29> in <module>()
#       9 plt.figure(figsize=(5, 20))
#      10 for p in range(batch_size):
# ---> 11     plt.subplot(10, 2, p+1)
#      12     plt.imshow(recon_x[p].view(28, 28).data.numpy())
#      13     plt.axis('off')
#
# ~/anaconda2/envs/clustering/lib/python3.5/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1081
#    1082     fig = gcf()
# -> 1083     a = fig.add_subplot(*args, **kwargs)
#    1084     bbox = a.bbox
#    1085     byebye = []
#
# ~/anaconda2/envs/clustering/lib/python3.5/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1368                     self._axstack.remove(ax)
#    1369
# -> 1370             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1371         self._axstack.add(key, a)
#    1372         self.sca(a)
#
# ~/anaconda2/envs/clustering/lib/python3.5/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      58                     raise ValueError(
#      59                         ("num must be 1 <= num <= {maxn}, not {num}"
# ---> 60                         ).format(maxn=rows*cols, num=num))
#      61                 self._subplotspec = GridSpec(
#      62                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 20, not 21

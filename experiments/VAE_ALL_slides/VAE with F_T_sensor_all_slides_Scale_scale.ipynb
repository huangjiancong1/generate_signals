# %% [markdown]
# ## Use scale to pre-processing

# %%
import os
import time
import torch
import argparse
import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
from torchvision import transforms
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader
from collections import defaultdict
import torch.multiprocessing as mp
import torch.utils.data
import torch
import numpy as np
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler
import torch.nn as nn
import numpy

from sklearn import preprocessing

from models import VAE


device = torch.device('cuda:0')

# convert data to torch.FloatTensor
transform = transforms.ToTensor()

# load the training and test datasets
# train_data = datasets.MNIST(root='data', train=True,
#                                    download=True, transform=transform)
# test_data = datasets.MNIST(root='data', train=False,
#                                   download=True, transform=transform)

# data_loader = DataLoader(
#     dataset=dataset, batch_size=args.batch_size, shuffle=True)
# print(len(train_data))

# dataset = MNIST(
#     root='data', train=True, transform=transforms.ToTensor(),
#     download=True)


sides_3 = np.load('../data/force_torque_sensor/Dataset/3_sides/Data/data.npy')
sides_4 = np.load('../data/force_torque_sensor/Dataset/4_sides/Data/data.npy')
sides_5 = np.load('../data/force_torque_sensor/Dataset/5_sides/Data/data.npy')
sides_6 = np.load('../data/force_torque_sensor/Dataset/6_sides/Data/data.npy')
sides_200 = np.load('../data/force_torque_sensor/Dataset/200_sides/Data/data.npy')

# %%
def feature_normalize(data):
    mu = np.mean(data,axis=0)
    std = np.std(data,axis=0)
    return (data - mu)/std

def un_normalize(normalized_data, input_data):
    mu = np.mean(input_data,axis=0)
    std = np.std(input_data,axis=0)
    return normalized_data*std+mu

# %%
def extract_trials(x, n):
#     x = feature_normalize(x)
    x = preprocessing.minmax_scale(x, feature_range=(0,1))
    trials=[]
    trial=[]
    compare=0
    for sig in x:
        trial.append(sig[0:n])
        if sig[11] <= compare:
            d = 1002 - len(trial)
            if d >0:
                for i in range(d):
                    trial.append(np.zeros(len(sig[0:n])))
            trials.append(trial)
            trial=[]
        compare=sig[11]
    trials = np.array(trials)
    return trials

# %%
num=10

sides_3_trials = extract_trials(sides_3, num)
# sides_4_trials = extract_trials(sides_4, num)
# sides_5_trials = extract_trials(sides_5, num)
# sides_6_trials = extract_trials(sides_6, num)
# sides_200_trials = extract_trials(sides_200, num)




print(sides_3[0])

print(np.shape(sides_3_trials))
print(len(sides_3_trials[1000]))
print(sides_3_trials[1000])
# Out:
# [-8.47151862e-03 -8.44647365e-03 -1.92757998e-05 -8.72229118e-02
#  -8.22633362e-01  4.80666690e-02 -3.33000795e-02 -5.22700006e-02
#  -7.75166669e-02  8.91666770e-03  1.00000000e+00  7.11917877e-04]
# (1583, 1002, 10)
# 1002
# [[0.99761829 0.35669136 0.6230216  ... 0.81527376 0.65169391 0.60907035]
#  [0.99761829 0.35669136 0.6230216  ... 0.81747967 0.64997979 0.57950256]
#  [0.99761829 0.35669136 0.6230216  ... 0.83126661 0.61341184 0.57412659]
#  ...
#  [0.99761829 0.35669136 0.6230216  ... 0.82244296 0.6076981  0.59563043]
#  [0.99598465 0.44840978 0.51779794 ... 0.79430618 0.67270165 0.65831302]
#  [0.         0.         0.         ... 0.         0.         0.        ]]

# %%
sides_3_trials = sides_3_trials[0:1530]
dataset = sides_3_trials

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 10

data_loader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True)
train_loader = data_loader
valid_loader = data_loader
test_loader = data_loader

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
    
# obtain one batch of training images
dataiter = iter(data_loader)
images = dataiter.next()
images = images.numpy()

# get one image from the batch
img = np.squeeze(images[0])

fig = plt.figure(figsize = (5,500)) 
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')

# %% [markdown]
# ## Loss function

# %%
def loss_fn(recon_x, x, mean, log_var):
    BCE = torch.nn.functional.binary_cross_entropy(recon_x.view(-1, 1002*10), x.view(-1, 1002*10), reduction='sum')
    KLD = -0.5 * torch.sum(1 + log_var - mean.pow(2) - log_var.exp())
    # elbo = recon_loss + self.beta * D_kl
    elbo = (BCE + KLD)/ x.size(0)
    return elbo

# %%
seed = 0
epochs = 50
latent_size = 2
num_processes = 2
learning_rate = 0.001
print_every = 100


vae = VAE(latent_size=latent_size).float().to(device)

# vae = VAE(
#     encoder_layer_sizes=encoder_layer_sizes,
#     latent_size=latent_size,
#     decoder_layer_sizes=decoder_layer_sizes).to(device)

use_cuda = torch.cuda.is_available
if use_cuda:
    vae.to(device)

logs = defaultdict(list)
    
epochs = epochs
for epoch in range(epochs):
    lr_havel = learning_rate
    optimizer = torch.optim.Adam(vae.parameters(), lr=lr_havel)
    
    for iteration, data in enumerate(train_loader):
        signals = data
        signals = signals.view(signals.size(0), -1)
        if use_cuda:
            signals = signals.to(device).float()
        else:
            signals = signals.float()

        optimizer.zero_grad()
        recon_x, mean, log_var, z = vae(signals)
        elbo = loss_fn(recon_x, signals, mean, log_var)
        loss = elbo
        loss.backward()
        optimizer.step()

        logs['loss'].append(loss.item())

        if iteration % print_every == 0 or iteration == len(train_loader)-1:
            valid_correct = 0
            valid_total = 0
            test_correct = 0
            test_total = 0

            for valid_data in valid_loader:
                valid = valid_data
                valid = signals.view(valid.size(0), -1)
                if use_cuda:
                    input_valid = valid.to(device).float()
                else:
                    input_valid = valid.float()
                valid_recon_x, valid_mean, valid_log_var, valid_z = vae(input_valid)
                valid_elbo = loss_fn(valid_recon_x, input_valid, valid_mean, valid_log_var)
                criterion = nn.MSELoss()
                valid_loss = criterion(valid_recon_x, input_valid)
                logs['valid_elbo'].append(valid_elbo.item())
                logs['valid_loss'].append(valid_loss.item())
                valid_total +=1
                if valid_loss < 0.05:
                    valid_correct += 1
            valid_acc = valid_correct / valid_total  
            print("Epoch {:02d}/{:02d} Batch {:04d}/{:d} |Train_ELBO {:5f} |Valid_ELBO{:5f} |Valid_loss{:5f} |Valid_accuary{:5f} |Leaarning_rate{:5f}".format(
                epoch, epochs, iteration, len(train_loader)-1, loss.item(), valid_elbo.item(), valid_loss.item(), valid_acc, lr_havel))

    lr_havel = lr_havel*0.9
    torch.save(vae, 'vae_all_signals_1002_scale_0_1_unscale.pkl')
# Out:
# Epoch 00/50 Batch 0000/152 |Train_ELBO 7208.761230 |Valid_ELBO7209.551758 |Valid_loss0.065587 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 00/50 Batch 0100/152 |Train_ELBO 6521.925781 |Valid_ELBO6444.089844 |Valid_loss0.039404 |Valid_accuary0.973856 |Leaarning_rate0.001000
# Epoch 00/50 Batch 0152/152 |Train_ELBO 6272.028809 |Valid_ELBO6419.882812 |Valid_loss0.030092 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 01/50 Batch 0000/152 |Train_ELBO 6347.458008 |Valid_ELBO6569.982910 |Valid_loss0.040532 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 01/50 Batch 0100/152 |Train_ELBO 6281.300293 |Valid_ELBO6340.961426 |Valid_loss0.028011 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 01/50 Batch 0152/152 |Train_ELBO 6346.653809 |Valid_ELBO6435.548340 |Valid_loss0.028815 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 02/50 Batch 0000/152 |Train_ELBO 6187.587891 |Valid_ELBO6495.452637 |Valid_loss0.030081 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 02/50 Batch 0100/152 |Train_ELBO 6422.510254 |Valid_ELBO6443.459961 |Valid_loss0.019952 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 02/50 Batch 0152/152 |Train_ELBO 6109.693848 |Valid_ELBO6069.976074 |Valid_loss0.012963 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 03/50 Batch 0000/152 |Train_ELBO 6217.596191 |Valid_ELBO6410.018066 |Valid_loss0.024928 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 03/50 Batch 0100/152 |Train_ELBO 6139.655273 |Valid_ELBO6128.149902 |Valid_loss0.021693 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 03/50 Batch 0152/152 |Train_ELBO 6349.500977 |Valid_ELBO6372.562500 |Valid_loss0.029239 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 04/50 Batch 0000/152 |Train_ELBO 6224.614746 |Valid_ELBO6273.738770 |Valid_loss0.023552 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 04/50 Batch 0100/152 |Train_ELBO 6110.787598 |Valid_ELBO6066.464355 |Valid_loss0.017590 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 04/50 Batch 0152/152 |Train_ELBO 6311.896973 |Valid_ELBO6121.476074 |Valid_loss0.013192 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 05/50 Batch 0000/152 |Train_ELBO 6149.921387 |Valid_ELBO6209.647949 |Valid_loss0.018505 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 05/50 Batch 0100/152 |Train_ELBO 6480.660156 |Valid_ELBO6462.405762 |Valid_loss0.026714 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 05/50 Batch 0152/152 |Train_ELBO 6236.605469 |Valid_ELBO6177.670410 |Valid_loss0.014402 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 06/50 Batch 0000/152 |Train_ELBO 6098.110840 |Valid_ELBO5927.819824 |Valid_loss0.018543 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 06/50 Batch 0100/152 |Train_ELBO 6124.398926 |Valid_ELBO6249.939453 |Valid_loss0.029116 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 06/50 Batch 0152/152 |Train_ELBO 6238.340332 |Valid_ELBO6296.879883 |Valid_loss0.026013 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 07/50 Batch 0000/152 |Train_ELBO 6192.320801 |Valid_ELBO6311.553711 |Valid_loss0.029199 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 07/50 Batch 0100/152 |Train_ELBO 6319.733398 |Valid_ELBO6311.635742 |Valid_loss0.024543 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 07/50 Batch 0152/152 |Train_ELBO 6159.962402 |Valid_ELBO6086.930176 |Valid_loss0.016823 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 08/50 Batch 0000/152 |Train_ELBO 6187.044434 |Valid_ELBO6135.224121 |Valid_loss0.013752 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 08/50 Batch 0100/152 |Train_ELBO 6181.729492 |Valid_ELBO6214.912598 |Valid_loss0.025050 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 08/50 Batch 0152/152 |Train_ELBO 6054.305176 |Valid_ELBO6015.078613 |Valid_loss0.014517 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 09/50 Batch 0000/152 |Train_ELBO 6222.198242 |Valid_ELBO6120.337402 |Valid_loss0.016600 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 09/50 Batch 0100/152 |Train_ELBO 6078.603516 |Valid_ELBO6160.749023 |Valid_loss0.019499 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 09/50 Batch 0152/152 |Train_ELBO 6171.766113 |Valid_ELBO6008.827148 |Valid_loss0.015355 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 10/50 Batch 0000/152 |Train_ELBO 6195.054199 |Valid_ELBO6101.197754 |Valid_loss0.021191 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 10/50 Batch 0100/152 |Train_ELBO 6318.995605 |Valid_ELBO6303.985840 |Valid_loss0.029400 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 10/50 Batch 0152/152 |Train_ELBO 6209.862793 |Valid_ELBO6084.083496 |Valid_loss0.013880 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 11/50 Batch 0000/152 |Train_ELBO 6161.462402 |Valid_ELBO6126.118652 |Valid_loss0.016529 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 11/50 Batch 0100/152 |Train_ELBO 6401.435547 |Valid_ELBO6336.138184 |Valid_loss0.027562 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 11/50 Batch 0152/152 |Train_ELBO 6384.496094 |Valid_ELBO6436.563965 |Valid_loss0.030300 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 12/50 Batch 0000/152 |Train_ELBO 6314.590820 |Valid_ELBO6256.672363 |Valid_loss0.022550 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 12/50 Batch 0100/152 |Train_ELBO 6225.916992 |Valid_ELBO6194.843262 |Valid_loss0.015264 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 12/50 Batch 0152/152 |Train_ELBO 6089.020996 |Valid_ELBO6023.211426 |Valid_loss0.017414 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 13/50 Batch 0000/152 |Train_ELBO 6050.969727 |Valid_ELBO5935.284180 |Valid_loss0.012933 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 13/50 Batch 0100/152 |Train_ELBO 6308.552246 |Valid_ELBO6387.851074 |Valid_loss0.020201 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 13/50 Batch 0152/152 |Train_ELBO 6305.742676 |Valid_ELBO6328.808594 |Valid_loss0.019359 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 14/50 Batch 0000/152 |Train_ELBO 6117.763672 |Valid_ELBO6000.742188 |Valid_loss0.015104 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 14/50 Batch 0100/152 |Train_ELBO 6055.780762 |Valid_ELBO6024.992188 |Valid_loss0.013494 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 14/50 Batch 0152/152 |Train_ELBO 5996.649414 |Valid_ELBO6033.747070 |Valid_loss0.013308 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 15/50 Batch 0000/152 |Train_ELBO 5992.946289 |Valid_ELBO5830.934082 |Valid_loss0.012900 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 15/50 Batch 0100/152 |Train_ELBO 6270.594727 |Valid_ELBO6209.169922 |Valid_loss0.019715 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 15/50 Batch 0152/152 |Train_ELBO 6033.253906 |Valid_ELBO5963.969238 |Valid_loss0.015546 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 16/50 Batch 0000/152 |Train_ELBO 5933.138672 |Valid_ELBO5878.038574 |Valid_loss0.017697 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 16/50 Batch 0100/152 |Train_ELBO 6157.241211 |Valid_ELBO6133.014160 |Valid_loss0.021902 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 16/50 Batch 0152/152 |Train_ELBO 6309.633789 |Valid_ELBO6215.077637 |Valid_loss0.015296 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 17/50 Batch 0000/152 |Train_ELBO 6092.602539 |Valid_ELBO5967.381836 |Valid_loss0.011120 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 17/50 Batch 0100/152 |Train_ELBO 5973.222656 |Valid_ELBO5980.144531 |Valid_loss0.012599 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 17/50 Batch 0152/152 |Train_ELBO 5798.072754 |Valid_ELBO6081.476562 |Valid_loss0.020381 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 18/50 Batch 0000/152 |Train_ELBO 5940.243652 |Valid_ELBO6082.809570 |Valid_loss0.022971 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 18/50 Batch 0100/152 |Train_ELBO 5967.217773 |Valid_ELBO5916.954590 |Valid_loss0.014067 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 18/50 Batch 0152/152 |Train_ELBO 5911.749512 |Valid_ELBO5866.614258 |Valid_loss0.010961 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 19/50 Batch 0000/152 |Train_ELBO 6109.761719 |Valid_ELBO5911.157227 |Valid_loss0.017420 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 19/50 Batch 0100/152 |Train_ELBO 5951.555176 |Valid_ELBO5969.564941 |Valid_loss0.016868 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 19/50 Batch 0152/152 |Train_ELBO 6023.358887 |Valid_ELBO5956.398926 |Valid_loss0.011336 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 20/50 Batch 0000/152 |Train_ELBO 6147.387207 |Valid_ELBO6137.180664 |Valid_loss0.016426 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 20/50 Batch 0100/152 |Train_ELBO 5945.413086 |Valid_ELBO5981.767578 |Valid_loss0.013581 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 20/50 Batch 0152/152 |Train_ELBO 6133.787598 |Valid_ELBO6096.524414 |Valid_loss0.010959 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 21/50 Batch 0000/152 |Train_ELBO 6217.410156 |Valid_ELBO6196.923340 |Valid_loss0.016297 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 21/50 Batch 0100/152 |Train_ELBO 5984.189453 |Valid_ELBO5899.718262 |Valid_loss0.011678 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 21/50 Batch 0152/152 |Train_ELBO 6197.132324 |Valid_ELBO6193.780762 |Valid_loss0.021140 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 22/50 Batch 0000/152 |Train_ELBO 6052.877441 |Valid_ELBO5837.831055 |Valid_loss0.011797 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 22/50 Batch 0100/152 |Train_ELBO 5918.391602 |Valid_ELBO5957.224121 |Valid_loss0.015134 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 22/50 Batch 0152/152 |Train_ELBO 6186.842285 |Valid_ELBO6033.460938 |Valid_loss0.017067 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 23/50 Batch 0000/152 |Train_ELBO 5923.329102 |Valid_ELBO5970.185059 |Valid_loss0.010883 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 23/50 Batch 0100/152 |Train_ELBO 5975.700195 |Valid_ELBO6047.803711 |Valid_loss0.013951 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 23/50 Batch 0152/152 |Train_ELBO 5895.056152 |Valid_ELBO5745.075684 |Valid_loss0.013271 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 24/50 Batch 0000/152 |Train_ELBO 6013.051758 |Valid_ELBO5934.912109 |Valid_loss0.014934 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 24/50 Batch 0100/152 |Train_ELBO 6009.424805 |Valid_ELBO5965.052734 |Valid_loss0.012291 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 24/50 Batch 0152/152 |Train_ELBO 6061.412109 |Valid_ELBO6099.652832 |Valid_loss0.013706 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 25/50 Batch 0000/152 |Train_ELBO 6000.734375 |Valid_ELBO5917.076660 |Valid_loss0.011176 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 25/50 Batch 0100/152 |Train_ELBO 6054.667480 |Valid_ELBO6052.318848 |Valid_loss0.014080 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 25/50 Batch 0152/152 |Train_ELBO 6012.205566 |Valid_ELBO5943.464355 |Valid_loss0.012130 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 26/50 Batch 0000/152 |Train_ELBO 6099.912109 |Valid_ELBO6006.656250 |Valid_loss0.016308 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 26/50 Batch 0100/152 |Train_ELBO 6121.493164 |Valid_ELBO6115.848145 |Valid_loss0.015557 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 26/50 Batch 0152/152 |Train_ELBO 6019.787598 |Valid_ELBO5933.009277 |Valid_loss0.011641 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 27/50 Batch 0000/152 |Train_ELBO 5952.803711 |Valid_ELBO5962.303711 |Valid_loss0.009014 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 27/50 Batch 0100/152 |Train_ELBO 6076.547852 |Valid_ELBO6122.485352 |Valid_loss0.014866 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 27/50 Batch 0152/152 |Train_ELBO 5916.750488 |Valid_ELBO6005.407715 |Valid_loss0.011962 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 28/50 Batch 0000/152 |Train_ELBO 6038.847168 |Valid_ELBO5966.256348 |Valid_loss0.013485 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 28/50 Batch 0100/152 |Train_ELBO 6048.002930 |Valid_ELBO6099.053711 |Valid_loss0.012829 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 28/50 Batch 0152/152 |Train_ELBO 5810.353027 |Valid_ELBO5865.874023 |Valid_loss0.012733 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 29/50 Batch 0000/152 |Train_ELBO 5932.181152 |Valid_ELBO5844.650879 |Valid_loss0.010122 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 29/50 Batch 0100/152 |Train_ELBO 6045.931152 |Valid_ELBO5920.933105 |Valid_loss0.011562 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 29/50 Batch 0152/152 |Train_ELBO 5981.329590 |Valid_ELBO5937.886230 |Valid_loss0.009766 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 30/50 Batch 0000/152 |Train_ELBO 6037.677246 |Valid_ELBO5890.672363 |Valid_loss0.014127 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 30/50 Batch 0100/152 |Train_ELBO 5957.390137 |Valid_ELBO5998.177246 |Valid_loss0.012934 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 30/50 Batch 0152/152 |Train_ELBO 5855.921387 |Valid_ELBO5822.278320 |Valid_loss0.015576 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 31/50 Batch 0000/152 |Train_ELBO 6062.876465 |Valid_ELBO5997.723145 |Valid_loss0.014134 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 31/50 Batch 0100/152 |Train_ELBO 5858.604980 |Valid_ELBO5830.333984 |Valid_loss0.009058 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 31/50 Batch 0152/152 |Train_ELBO 5967.834961 |Valid_ELBO5990.413086 |Valid_loss0.008334 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 32/50 Batch 0000/152 |Train_ELBO 5713.177734 |Valid_ELBO5695.544434 |Valid_loss0.011929 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 32/50 Batch 0100/152 |Train_ELBO 6050.029785 |Valid_ELBO6008.874512 |Valid_loss0.010411 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 32/50 Batch 0152/152 |Train_ELBO 6047.599121 |Valid_ELBO6009.724121 |Valid_loss0.016607 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 33/50 Batch 0000/152 |Train_ELBO 5925.134277 |Valid_ELBO5930.046387 |Valid_loss0.011475 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 33/50 Batch 0100/152 |Train_ELBO 5979.466309 |Valid_ELBO5907.279297 |Valid_loss0.007277 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 33/50 Batch 0152/152 |Train_ELBO 5887.059570 |Valid_ELBO5833.641602 |Valid_loss0.011661 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 34/50 Batch 0000/152 |Train_ELBO 5877.992188 |Valid_ELBO5842.159668 |Valid_loss0.006120 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 34/50 Batch 0100/152 |Train_ELBO 6153.798828 |Valid_ELBO6150.422363 |Valid_loss0.014115 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 34/50 Batch 0152/152 |Train_ELBO 6049.507324 |Valid_ELBO6046.625488 |Valid_loss0.012186 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 35/50 Batch 0000/152 |Train_ELBO 5990.869141 |Valid_ELBO5911.451660 |Valid_loss0.008691 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 35/50 Batch 0100/152 |Train_ELBO 5896.656250 |Valid_ELBO5888.389160 |Valid_loss0.007576 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 35/50 Batch 0152/152 |Train_ELBO 5863.572754 |Valid_ELBO5860.479492 |Valid_loss0.008097 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 36/50 Batch 0000/152 |Train_ELBO 5899.510254 |Valid_ELBO5824.062500 |Valid_loss0.007808 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 36/50 Batch 0100/152 |Train_ELBO 5965.427734 |Valid_ELBO5926.007324 |Valid_loss0.014270 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 36/50 Batch 0152/152 |Train_ELBO 5991.593750 |Valid_ELBO5978.493652 |Valid_loss0.007182 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 37/50 Batch 0000/152 |Train_ELBO 5899.015137 |Valid_ELBO5794.695312 |Valid_loss0.007644 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 37/50 Batch 0100/152 |Train_ELBO 5904.877930 |Valid_ELBO5948.726074 |Valid_loss0.013524 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 37/50 Batch 0152/152 |Train_ELBO 6022.194336 |Valid_ELBO6020.911621 |Valid_loss0.010537 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 38/50 Batch 0000/152 |Train_ELBO 5997.399414 |Valid_ELBO6002.518555 |Valid_loss0.007241 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 38/50 Batch 0100/152 |Train_ELBO 5888.360352 |Valid_ELBO6057.750977 |Valid_loss0.019112 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 38/50 Batch 0152/152 |Train_ELBO 5844.838379 |Valid_ELBO5831.142090 |Valid_loss0.013366 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 39/50 Batch 0000/152 |Train_ELBO 6058.366699 |Valid_ELBO6015.792480 |Valid_loss0.016241 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 39/50 Batch 0100/152 |Train_ELBO 5962.239746 |Valid_ELBO5968.561035 |Valid_loss0.006719 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 39/50 Batch 0152/152 |Train_ELBO 5994.234863 |Valid_ELBO5995.100586 |Valid_loss0.008759 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 40/50 Batch 0000/152 |Train_ELBO 5763.744629 |Valid_ELBO5741.656250 |Valid_loss0.007499 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 40/50 Batch 0100/152 |Train_ELBO 5949.080566 |Valid_ELBO5895.955078 |Valid_loss0.008886 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 40/50 Batch 0152/152 |Train_ELBO 5815.365723 |Valid_ELBO5786.917480 |Valid_loss0.012425 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 41/50 Batch 0000/152 |Train_ELBO 5813.361816 |Valid_ELBO5767.212891 |Valid_loss0.006628 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 41/50 Batch 0100/152 |Train_ELBO 6019.315430 |Valid_ELBO5981.634766 |Valid_loss0.011660 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 41/50 Batch 0152/152 |Train_ELBO 5943.734375 |Valid_ELBO5989.861328 |Valid_loss0.008254 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 42/50 Batch 0000/152 |Train_ELBO 5896.812012 |Valid_ELBO5873.112305 |Valid_loss0.014633 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 42/50 Batch 0100/152 |Train_ELBO 5886.862793 |Valid_ELBO5898.191406 |Valid_loss0.009526 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 42/50 Batch 0152/152 |Train_ELBO 5888.210449 |Valid_ELBO5824.917480 |Valid_loss0.011780 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 43/50 Batch 0000/152 |Train_ELBO 5803.262695 |Valid_ELBO5709.604492 |Valid_loss0.006396 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 43/50 Batch 0100/152 |Train_ELBO 5918.500977 |Valid_ELBO5906.182617 |Valid_loss0.008492 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 43/50 Batch 0152/152 |Train_ELBO 5915.664551 |Valid_ELBO5840.150391 |Valid_loss0.011425 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 44/50 Batch 0000/152 |Train_ELBO 5975.597168 |Valid_ELBO5932.042480 |Valid_loss0.013892 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 44/50 Batch 0100/152 |Train_ELBO 6059.655273 |Valid_ELBO6067.370117 |Valid_loss0.009406 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 44/50 Batch 0152/152 |Train_ELBO 5824.704590 |Valid_ELBO5838.085449 |Valid_loss0.008905 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 45/50 Batch 0000/152 |Train_ELBO 5934.448730 |Valid_ELBO5891.000488 |Valid_loss0.004950 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 45/50 Batch 0100/152 |Train_ELBO 5789.652832 |Valid_ELBO5760.490723 |Valid_loss0.007147 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 45/50 Batch 0152/152 |Train_ELBO 6068.235352 |Valid_ELBO6062.748535 |Valid_loss0.020623 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 46/50 Batch 0000/152 |Train_ELBO 5966.385254 |Valid_ELBO5923.875000 |Valid_loss0.009009 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 46/50 Batch 0100/152 |Train_ELBO 5945.267578 |Valid_ELBO5893.071289 |Valid_loss0.013949 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 46/50 Batch 0152/152 |Train_ELBO 6101.187012 |Valid_ELBO6075.374512 |Valid_loss0.014594 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 47/50 Batch 0000/152 |Train_ELBO 6062.842285 |Valid_ELBO5999.692871 |Valid_loss0.011859 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 47/50 Batch 0100/152 |Train_ELBO 5832.724121 |Valid_ELBO5815.787109 |Valid_loss0.006441 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 47/50 Batch 0152/152 |Train_ELBO 6040.472168 |Valid_ELBO6022.997559 |Valid_loss0.016780 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 48/50 Batch 0000/152 |Train_ELBO 5911.875488 |Valid_ELBO5923.852051 |Valid_loss0.009248 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 48/50 Batch 0100/152 |Train_ELBO 5970.902344 |Valid_ELBO5921.326660 |Valid_loss0.009932 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 48/50 Batch 0152/152 |Train_ELBO 5978.519043 |Valid_ELBO6014.483887 |Valid_loss0.022364 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 49/50 Batch 0000/152 |Train_ELBO 5710.499512 |Valid_ELBO5657.604004 |Valid_loss0.006926 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 49/50 Batch 0100/152 |Train_ELBO 6155.159668 |Valid_ELBO6083.806641 |Valid_loss0.010133 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 49/50 Batch 0152/152 |Train_ELBO 5923.925293 |Valid_ELBO5889.373047 |Valid_loss0.010919 |Valid_accuary1.000000 |Leaarning_rate0.001000

# %% [markdown]
# # 2. Use the oringinal signal to Generate>>>>>>

# %%
vae = torch.load('vae_all_signals_1002_scale_0_1_unscale.pkl').to(device)

# %%
import torch.utils.data

batch_size = 10
test_loader = data_loader

vae=vae.to(device)


recon_signals=[]
latent_space=[]

for iteration, test in enumerate(test_loader):
    test = test.view(test.size(0), -1)
    test = test.to(device).float()
    test_recon_x, test_mean, test_log_var, test_z = vae(test)
    test_recon_x = test_recon_x.view(batch_size, 1002, 10)
    test_recon_x=test_recon_x.cpu().detach().numpy()
    latent_space=test_z.cpu().detach().numpy()

    recon_signals.extend(test_recon_x)
#     latent_space.extend(latent_space)
    
    if iteration ==10:
        break
    
recon_signals = np.array(recon_signals)
latent_space = np.array(latent_space)

# %%
print(type(recon_signals[0]))
print(recon_signals[0])

print(len(recon_signals))
print(len(recon_signals[0]))
# print(recon_signals)
# Out:
# <class 'numpy.ndarray'>
# [[0.5078503  0.6857545  0.49616787 ... 0.8317243  0.62283075 0.59991586]
#  [0.505258   0.6854868  0.497572   ... 0.826713   0.6297612  0.6049696 ]
#  [0.50561035 0.68453306 0.49381882 ... 0.83126396 0.64568126 0.5895931 ]
#  ...
#  [0.5096192  0.69571996 0.49794355 ... 0.828201   0.64046514 0.6384261 ]
#  [0.45640352 0.52206963 0.3874171  ... 0.6733093  0.5089673  0.47040394]
#  [0.0107734  0.0116676  0.00776429 ... 0.01389404 0.01115226 0.00999529]]
# 110
# 1002

# %%
# for i in range(len(recon_signals[0])):
#     recon_signals[:,i]=preprocessing.minmax_scale(
#         recon_signals[:,i], feature_range=(np.min(sides_3_trials[:,i]),np.max(sides_3_trials[:,i])))


# # recon_signals = un_normalize(recon_signals, sides_3_trials)
# generate_signals = recon_signals

# np.min(sides_3_trials[:,i])

# %% [markdown]
# ## 2.1 Change shape

# %%
generate_signals=[]
for trial in recon_signals:
    generate_signals.extend(trial)
generate_signals = np.array(generate_signals)
print(np.shape(generate_signals))
# Out:
# (110220, 10)

# %% [markdown]
# ## 2.1 Un pre-process(here we can select to train use normalize or scale and also generate)

# %%
for i in range(len(generate_signals[0])):
    generate_signals[:,i]=preprocessing.minmax_scale(
        generate_signals[:,i], feature_range=(np.min(sides_3[:,i]),np.max(sides_3[:,i])))
    
generated_signals=generate_signals

print(generated_signals[100])
# Out:
# [8.5579697e-04 4.2491425e-03 1.5096612e-04 7.9910435e-02 2.5229988e+00
#  6.1574421e+00 1.1052055e+00 2.3284924e-01 3.9831042e-01 8.1001282e-02]

# %%
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt

cmap=plt.cm.get_cmap(plt.cm.viridis,143)


# plt.rcParams['font.size'] = 11.
# plt.rcParams['font.family'] = 'Comic Sans MS'
# plt.rcParams['axes.labelsize'] = 15.
# plt.rcParams['xtick.labelsize'] = 10.
# plt.rcParams['ytick.labelsize'] = 10.

plt.figure(figsize=(15,10))



sides = generated_signals
print(len(sides))

slip = 1200

# Peg_Position_x = sides[:,0]
Peg_Position_x = sides[:,0][:slip]
# Peg_Position_x = sides[:,0][0:10:slip]

# Peg_Position_y = sides[:,1]
Peg_Position_y = sides[:,1][:slip]
# Peg_Position_y = sides[:,1][0:10:slip]

# Peg_Position_z = sides[:,2]
Peg_Position_z = sides[:,2][:slip]
# Peg_Position_z = sides[:,2][0:10:slip]

# Angle = sides[:,3]
Angle = sides[:,3][:slip]
# Angle = sides[:,3][0:10:slip]

# Force_x = sides[:,4]
Force_x = sides[:,4][:slip]
# Force_x = sides[:,4][0:10:slip]

# Force_y = sides[:,5]
Force_y = sides[:,5][:slip]
# Force_y = sides[:,5][0:10:slip]

# Force_z = sides[:,6]
Force_z = sides[:,6][:slip]
# Force_z = sides[:,6][0:10:slip]

# Moment_x = sides[:,7]
Moment_x = sides[:,7][:slip]
# Moment_x = sides[:,7][0:10:slip]

# Moment_y = sides[:,8]
Moment_y = sides[:,8][:slip]
# Moment_y = sides[:,8][0:10:slip]

# Moment_z = sides[:,9]
Moment_z = sides[:,9][:slip]
# Moment_z = sides[:,9][0:10:slip]

x = np.linspace(0,len(Moment_z),len(Moment_z))

plt.plot(x, Force_x, marker='o', linestyle='-', markersize=2, linewidth=1, label='Force_x')
plt.plot(x, Force_y, marker='o', linestyle='-', markersize=2, linewidth=1, label='Force_y')
plt.plot(x, Force_z, marker='o', linestyle='-', markersize=2, linewidth=1, label='Force_z')

plt.plot(x, Moment_x, marker='o', linestyle='-', markersize=2, linewidth=1, label='Moment_x')
plt.plot(x, Moment_y, marker='o', linestyle='-', markersize=2, linewidth=1, label='Moment_y')
plt.plot(x, Moment_z, marker='o', linestyle='-', markersize=2, linewidth=1, label='Moment_z')

plt.plot(x, Peg_Position_x, marker='o', linestyle='-', markersize=2, linewidth=1, label='Peg_Position_x')
plt.plot(x, Peg_Position_y, marker='o', linestyle='-', markersize=2, linewidth=1, label='Peg_Position_y')
plt.plot(x, Peg_Position_z, marker='o', linestyle='-', markersize=2, linewidth=1, label='Peg_Position_z')

plt.plot(x, Angle, marker='o', linestyle='-', markersize=2, linewidth=1, label='Angle')
# plt.plot(x, Counter, marker='o', linestyle='-', markersize=2, linewidth=1, label='Counter')


plt.xlabel('Times')
plt.ylabel('Signals')
plt.title('Force Torque Signals(3 Siles)')
plt.legend(loc='lower right')
plt.show()
# Out:
# 110220

# %% [markdown]
# # 3. Use the random latent space to Generate>>>>>>

# %%
print(latent_space)
# Out:
# [[-0.21548453  4.5791078 ]
#  [-1.1720028   3.620516  ]
#  [-0.03519656 -4.5704403 ]
#  [-0.18837124  0.50341034]
#  [ 1.3249025  -3.3224432 ]
#  [ 0.651377   -0.4258017 ]
#  [ 0.5474846   0.75405306]
#  [-1.5499146   0.3711355 ]
#  [-1.4741602  -0.85560143]
#  [ 0.38231313  0.01183113]]

# %%
# batch_size = 10
z = torch.randn([batch_size, 2]).to(device)
print(z)

recon_x = vae.decoder(z)

print(recon_x)
print(np.shape(recon_x))
# Out:
# tensor([[-1.5520, -0.6660],
#         [-1.3850, -1.0850],
#         [ 1.1126, -0.9754],
#         [-0.9697, -0.0580],
#         [-0.7448,  0.0712],
#         [-0.0158,  0.3938],
#         [ 0.4615,  0.6816],
#         [-1.2391, -0.5450],
#         [ 0.3475,  0.9770],
#         [ 0.5593, -0.4817]], device='cuda:0')
# tensor([[0.4456, 0.3657, 0.4707,  ..., 0.0860, 0.0741, 0.0692],
#         [0.5117, 0.5692, 0.4437,  ..., 0.0178, 0.0149, 0.0140],
#         [0.2119, 0.9350, 0.5138,  ..., 0.0088, 0.0071, 0.0063],
#         ...,
#         [0.5345, 0.4157, 0.4378,  ..., 0.0274, 0.0226, 0.0211],
#         [0.1302, 0.3904, 0.4888,  ..., 0.0077, 0.0052, 0.0052],
#         [0.7990, 0.9205, 0.4823,  ..., 0.0041, 0.0034, 0.0033]],
#        device='cuda:0', grad_fn=<SigmoidBackward>)
# torch.Size([10, 10020])

# %%
print(type(recon_x[0]))
print(recon_x[0])

print(len(recon_x))
print(len(recon_x[0]))

print(recon_x[0])
# Out:
# <class 'torch.Tensor'>
# tensor([0.4456, 0.3657, 0.4707,  ..., 0.0860, 0.0741, 0.0692], device='cuda:0',
#        grad_fn=<SelectBackward>)
# 10
# 10020
# tensor([0.4456, 0.3657, 0.4707,  ..., 0.0860, 0.0741, 0.0692], device='cuda:0',
#        grad_fn=<SelectBackward>)

# %%
recon_x = recon_x.view(batch_size,1002,10)
# generate_signals = recon_x.cpu().detach().numpy()

generate_signals=[]
for trial in recon_x:
    trial = trial.cpu().detach().numpy()
    generate_signals.append(trial)
generate_signals = np.array(generate_signals)


# print(np.shape(generate_signals))
print(len(generate_signals[0]))
# print(generate_signals[0])
# print(type(generate_signals))
# Out:
# 1002

# %%
for i in range(len(generate_signals)):
    generate_signals[:,i]=preprocessing.minmax_scale(
        generate_signals[:,i], feature_range=(np.min(sides_3[:,i]),np.max(sides_3[:,i])))
    
generated_signals=generate_signals

print(len(generated_signals[0]))
# Out:
# 1002

# %%
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt

cmap=plt.cm.get_cmap(plt.cm.viridis,143)


# plt.rcParams['font.size'] = 11.
# plt.rcParams['font.family'] = 'Comic Sans MS'
# plt.rcParams['axes.labelsize'] = 15.
# plt.rcParams['xtick.labelsize'] = 10.
# plt.rcParams['ytick.labelsize'] = 10.

plt.figure(figsize=(15,10))



sides = generated_signals[9]
print(len(sides))

slip = 1200

# Peg_Position_x = sides[:,0]
Peg_Position_x = sides[:,0][:slip]
# Peg_Position_x = sides[:,0][0:10:slip]

# Peg_Position_y = sides[:,1]
Peg_Position_y = sides[:,1][:slip]
# Peg_Position_y = sides[:,1][0:10:slip]

# Peg_Position_z = sides[:,2]
Peg_Position_z = sides[:,2][:slip]
# Peg_Position_z = sides[:,2][0:10:slip]

# Angle = sides[:,3]
Angle = sides[:,3][:slip]
# Angle = sides[:,3][0:10:slip]

# Force_x = sides[:,4]
Force_x = sides[:,4][:slip]
# Force_x = sides[:,4][0:10:slip]

# Force_y = sides[:,5]
Force_y = sides[:,5][:slip]
# Force_y = sides[:,5][0:10:slip]

# Force_z = sides[:,6]
Force_z = sides[:,6][:slip]
# Force_z = sides[:,6][0:10:slip]

# Moment_x = sides[:,7]
Moment_x = sides[:,7][:slip]
# Moment_x = sides[:,7][0:10:slip]

# Moment_y = sides[:,8]
Moment_y = sides[:,8][:slip]
# Moment_y = sides[:,8][0:10:slip]

# Moment_z = sides[:,9]
Moment_z = sides[:,9][:slip]
# Moment_z = sides[:,9][0:10:slip]

x = np.linspace(0,len(Moment_z),len(Moment_z))

plt.plot(x, Force_x, marker='o', linestyle='-', markersize=2, linewidth=1, label='Force_x')
plt.plot(x, Force_y, marker='o', linestyle='-', markersize=2, linewidth=1, label='Force_y')
plt.plot(x, Force_z, marker='o', linestyle='-', markersize=2, linewidth=1, label='Force_z')

plt.plot(x, Moment_x, marker='o', linestyle='-', markersize=2, linewidth=1, label='Moment_x')
plt.plot(x, Moment_y, marker='o', linestyle='-', markersize=2, linewidth=1, label='Moment_y')
plt.plot(x, Moment_z, marker='o', linestyle='-', markersize=2, linewidth=1, label='Moment_z')

plt.plot(x, Peg_Position_x, marker='o', linestyle='-', markersize=2, linewidth=1, label='Peg_Position_x')
plt.plot(x, Peg_Position_y, marker='o', linestyle='-', markersize=2, linewidth=1, label='Peg_Position_y')
plt.plot(x, Peg_Position_z, marker='o', linestyle='-', markersize=2, linewidth=1, label='Peg_Position_z')

plt.plot(x, Angle, marker='o', linestyle='-', markersize=2, linewidth=1, label='Angle')
# plt.plot(x, Counter, marker='o', linestyle='-', markersize=2, linewidth=1, label='Counter')


plt.xlabel('Times')
plt.ylabel('Signals')
plt.title('Force Torque Signals(3 Siles)')
plt.legend(loc='lower right')
plt.show()
# Out:
# 1002

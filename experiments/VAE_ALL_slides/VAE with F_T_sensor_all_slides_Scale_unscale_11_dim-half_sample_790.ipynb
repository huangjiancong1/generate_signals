# %% [markdown]
# ## Use scale to pre-processing 11dim with time signals(only use half samples to generate)

# %% [markdown]
# ## 1.Pre-processing

# %%
import os
import time
import torch
import argparse
import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
from torchvision import transforms
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader
from collections import defaultdict
import torch.multiprocessing as mp
import torch.utils.data
import torch
import numpy as np
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler
import torch.nn as nn
import numpy

from sklearn import preprocessing

from models_11dim import VAE


device = torch.device('cuda:0')

# convert data to torch.FloatTensor
transform = transforms.ToTensor()

# load the training and test datasets
# train_data = datasets.MNIST(root='data', train=True,
#                                    download=True, transform=transform)
# test_data = datasets.MNIST(root='data', train=False,
#                                   download=True, transform=transform)

# data_loader = DataLoader(
#     dataset=dataset, batch_size=args.batch_size, shuffle=True)
# print(len(train_data))

# dataset = MNIST(
#     root='data', train=True, transform=transforms.ToTensor(),
#     download=True)


sides_3 = np.load('../data/force_torque_sensor/Dataset/3_sides/Data/data.npy')
sides_4 = np.load('../data/force_torque_sensor/Dataset/4_sides/Data/data.npy')
sides_5 = np.load('../data/force_torque_sensor/Dataset/5_sides/Data/data.npy')
sides_6 = np.load('../data/force_torque_sensor/Dataset/6_sides/Data/data.npy')
sides_200 = np.load('../data/force_torque_sensor/Dataset/200_sides/Data/data.npy')

# %%
def feature_normalize(data):
    mu = np.mean(data,axis=0)
    std = np.std(data,axis=0)
    return (data - mu)/std

def un_normalize(normalized_data, input_data):
    mu = np.mean(input_data,axis=0)
    std = np.std(input_data,axis=0)
    return normalized_data*std+mu

# %%
def extract_trials(x, n):
#     x = feature_normalize(x)
    x = preprocessing.minmax_scale(x, feature_range=(0,1))
    trials=[]
    trial=[]
    compare=0
    for sig in x:
        trial.append(sig[0:n])
        if sig[11] <= compare:
            d = 1002 - len(trial)
            if d >0:
                for i in range(d):
                    trial.append(np.zeros(len(sig[0:n])))
            trials.append(trial)
            trial=[]
        compare=sig[11]
    trials = np.array(trials)
    return trials

# %%
dim=11 # without select the time and counter signal

sides_3_trials = extract_trials(sides_3, dim)
# sides_4_trials = extract_trials(sides_4, num)
# sides_5_trials = extract_trials(sides_5, num)
# sides_6_trials = extract_trials(sides_6, num)
# sides_200_trials = extract_trials(sides_200, num)

print(sides_3_trials[1580][999])

print(np.shape(sides_3_trials))
print(len(sides_3_trials[1000]))
print(sides_3_trials[1000])
# Out:
# [0.99409463 0.81367002 0.48168194 0.99903415 0.62487198 0.29022964
#  0.95047635 0.82071828 0.62483573 0.633718   0.99873658]
# (1583, 1002, 11)
# 1002
# [[0.99761829 0.35669136 0.6230216  ... 0.65169391 0.60907035 0.63171194]
#  [0.99761829 0.35669136 0.6230216  ... 0.64997979 0.57950256 0.63171194]
#  [0.99761829 0.35669136 0.6230216  ... 0.61341184 0.57412659 0.63171194]
#  ...
#  [0.99761829 0.35669136 0.6230216  ... 0.6076981  0.59563043 0.63171194]
#  [0.99598465 0.44840978 0.51779794 ... 0.67270165 0.65831302 0.63234365]
#  [0.         0.         0.         ... 0.         0.         0.        ]]

# %% [markdown]
# ### Select the samples

# %%
sides_3_trials = sides_3_trials[0:1580]

print(len(sides_3_trials))

limit_trials=[]
count = 0

for trail in sides_3_trials:
    if count % 2 ==1:
        limit_trials.append(trail)
    count+=1

print(len(limit_trials))
# Out:
# 1580
# 790

# %%
dataset = limit_trials

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 10

data_loader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True)
train_loader = data_loader
valid_loader = data_loader
test_loader = data_loader

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
    
# obtain one batch of training images
dataiter = iter(data_loader)
images = dataiter.next()
images = images.numpy()

# get one image from the batch
img = np.squeeze(images[0])

fig = plt.figure(figsize = (5,500)) 
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')

# %% [markdown]
# ## Loss function

# %%
def loss_fn(recon_x, x, mean, log_var):
    BCE = torch.nn.functional.binary_cross_entropy(recon_x.view(-1, 1002*11), x.view(-1, 1002*11), reduction='sum')
    KLD = -0.5 * torch.sum(1 + log_var - mean.pow(2) - log_var.exp())
    # elbo = recon_loss + self.beta * D_kl
    elbo = (BCE + KLD)/ x.size(0)
    return elbo

# %%
seed = 0
epochs = 50
latent_size = 2
num_processes = 2
learning_rate = 0.001
print_every = 100


vae = VAE(latent_size=latent_size).float().to(device)

# vae = VAE(
#     encoder_layer_sizes=encoder_layer_sizes,
#     latent_size=latent_size,
#     decoder_layer_sizes=decoder_layer_sizes).to(device)

use_cuda = torch.cuda.is_available
if use_cuda:
    vae.to(device)

logs = defaultdict(list)
    
epochs = epochs
for epoch in range(epochs):
    lr_havel = learning_rate
    optimizer = torch.optim.Adam(vae.parameters(), lr=lr_havel)
    
    for iteration, data in enumerate(train_loader):
        signals = data
        signals = signals.view(signals.size(0), -1)
        if use_cuda:
            signals = signals.to(device).float()
        else:
            signals = signals.float()

        optimizer.zero_grad()
        recon_x, mean, log_var, z = vae(signals)
        elbo = loss_fn(recon_x, signals, mean, log_var)
        loss = elbo
        loss.backward()
        optimizer.step()

        logs['loss'].append(loss.item())

        if iteration % print_every == 0 or iteration == len(train_loader)-1:
            valid_correct = 0
            valid_total = 0
            test_correct = 0
            test_total = 0

            for valid_data in valid_loader:
                valid = valid_data
                valid = signals.view(valid.size(0), -1)
                if use_cuda:
                    input_valid = valid.to(device).float()
                else:
                    input_valid = valid.float()
                valid_recon_x, valid_mean, valid_log_var, valid_z = vae(input_valid)
                valid_elbo = loss_fn(valid_recon_x, input_valid, valid_mean, valid_log_var)
                criterion = nn.MSELoss()
                valid_loss = criterion(valid_recon_x, input_valid)
                logs['valid_elbo'].append(valid_elbo.item())
                logs['valid_loss'].append(valid_loss.item())
                valid_total +=1
                if valid_loss < 0.05:
                    valid_correct += 1
            valid_acc = valid_correct / valid_total  
            print("Epoch {:02d}/{:02d} Batch {:04d}/{:d} |Train_ELBO {:5f} |Valid_ELBO{:5f} |Valid_loss{:5f} |Valid_accuary{:5f} |Leaarning_rate{:5f}".format(
                epoch, epochs, iteration, len(train_loader)-1, loss.item(), valid_elbo.item(), valid_loss.item(), valid_acc, lr_havel))

    lr_havel = lr_havel*0.9
    torch.save(vae, 'vae_all_signals_1002_scale_unscale_11dim_half_sample.pkl')
# Out:
# Epoch 00/50 Batch 0000/78 |Train_ELBO 7928.768066 |Valid_ELBO7938.760254 |Valid_loss0.066320 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 00/50 Batch 0078/78 |Train_ELBO 7114.134277 |Valid_ELBO7390.874512 |Valid_loss0.038059 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 01/50 Batch 0000/78 |Train_ELBO 7228.557129 |Valid_ELBO7418.987793 |Valid_loss0.040068 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 01/50 Batch 0078/78 |Train_ELBO 6709.886719 |Valid_ELBO6697.133789 |Valid_loss0.028919 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 02/50 Batch 0000/78 |Train_ELBO 6974.021973 |Valid_ELBO6860.103027 |Valid_loss0.027767 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 02/50 Batch 0078/78 |Train_ELBO 7371.960938 |Valid_ELBO7207.963379 |Valid_loss0.038015 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 03/50 Batch 0000/78 |Train_ELBO 6889.028809 |Valid_ELBO7302.857910 |Valid_loss0.035860 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 03/50 Batch 0078/78 |Train_ELBO 6884.662598 |Valid_ELBO6806.359375 |Valid_loss0.026825 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 04/50 Batch 0000/78 |Train_ELBO 6799.454590 |Valid_ELBO6842.166504 |Valid_loss0.023741 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 04/50 Batch 0078/78 |Train_ELBO 6713.632324 |Valid_ELBO6714.671387 |Valid_loss0.021097 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 05/50 Batch 0000/78 |Train_ELBO 6603.938965 |Valid_ELBO6765.263184 |Valid_loss0.027448 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 05/50 Batch 0078/78 |Train_ELBO 6940.895508 |Valid_ELBO6776.291504 |Valid_loss0.019847 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 06/50 Batch 0000/78 |Train_ELBO 7001.639160 |Valid_ELBO6981.886719 |Valid_loss0.024082 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 06/50 Batch 0078/78 |Train_ELBO 6682.549316 |Valid_ELBO6683.860840 |Valid_loss0.020992 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 07/50 Batch 0000/78 |Train_ELBO 6809.852539 |Valid_ELBO6664.476074 |Valid_loss0.029962 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 07/50 Batch 0078/78 |Train_ELBO 6673.376465 |Valid_ELBO6785.174316 |Valid_loss0.031463 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 08/50 Batch 0000/78 |Train_ELBO 6952.726074 |Valid_ELBO7090.860840 |Valid_loss0.025623 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 08/50 Batch 0078/78 |Train_ELBO 6640.128418 |Valid_ELBO6413.409180 |Valid_loss0.020773 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 09/50 Batch 0000/78 |Train_ELBO 6683.085449 |Valid_ELBO6637.396973 |Valid_loss0.026054 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 09/50 Batch 0078/78 |Train_ELBO 6928.554688 |Valid_ELBO6909.968750 |Valid_loss0.026834 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 10/50 Batch 0000/78 |Train_ELBO 6837.417480 |Valid_ELBO6639.700684 |Valid_loss0.018078 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 10/50 Batch 0078/78 |Train_ELBO 6732.506348 |Valid_ELBO6808.917480 |Valid_loss0.023526 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 11/50 Batch 0000/78 |Train_ELBO 6813.808594 |Valid_ELBO6963.236816 |Valid_loss0.028914 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 11/50 Batch 0078/78 |Train_ELBO 6816.379883 |Valid_ELBO6461.648926 |Valid_loss0.013625 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 12/50 Batch 0000/78 |Train_ELBO 6808.209473 |Valid_ELBO6908.051758 |Valid_loss0.025593 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 12/50 Batch 0078/78 |Train_ELBO 6978.240723 |Valid_ELBO6946.698730 |Valid_loss0.019520 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 13/50 Batch 0000/78 |Train_ELBO 6582.674316 |Valid_ELBO6664.127441 |Valid_loss0.020963 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 13/50 Batch 0078/78 |Train_ELBO 6959.114258 |Valid_ELBO7239.937500 |Valid_loss0.027608 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 14/50 Batch 0000/78 |Train_ELBO 6636.480469 |Valid_ELBO6535.192871 |Valid_loss0.016756 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 14/50 Batch 0078/78 |Train_ELBO 7103.450195 |Valid_ELBO7101.095215 |Valid_loss0.022295 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 15/50 Batch 0000/78 |Train_ELBO 6680.127441 |Valid_ELBO6601.356445 |Valid_loss0.016114 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 15/50 Batch 0078/78 |Train_ELBO 6858.876465 |Valid_ELBO6763.834473 |Valid_loss0.023397 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 16/50 Batch 0000/78 |Train_ELBO 6932.402344 |Valid_ELBO6919.895996 |Valid_loss0.017964 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 16/50 Batch 0078/78 |Train_ELBO 6916.209473 |Valid_ELBO6973.023438 |Valid_loss0.025418 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 17/50 Batch 0000/78 |Train_ELBO 7112.610352 |Valid_ELBO7006.480469 |Valid_loss0.024979 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 17/50 Batch 0078/78 |Train_ELBO 7302.231445 |Valid_ELBO7284.124512 |Valid_loss0.039239 |Valid_accuary0.987342 |Leaarning_rate0.001000
# Epoch 18/50 Batch 0000/78 |Train_ELBO 6711.593750 |Valid_ELBO6579.280762 |Valid_loss0.019277 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 18/50 Batch 0078/78 |Train_ELBO 6895.811035 |Valid_ELBO6818.767090 |Valid_loss0.013514 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 19/50 Batch 0000/78 |Train_ELBO 6573.775879 |Valid_ELBO6440.178711 |Valid_loss0.023203 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 19/50 Batch 0078/78 |Train_ELBO 6944.913574 |Valid_ELBO6885.403320 |Valid_loss0.020444 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 20/50 Batch 0000/78 |Train_ELBO 7043.001465 |Valid_ELBO6688.355469 |Valid_loss0.021711 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 20/50 Batch 0078/78 |Train_ELBO 6943.282227 |Valid_ELBO6820.583008 |Valid_loss0.023333 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 21/50 Batch 0000/78 |Train_ELBO 6924.510254 |Valid_ELBO7042.377441 |Valid_loss0.033584 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 21/50 Batch 0078/78 |Train_ELBO 6873.968262 |Valid_ELBO6818.252441 |Valid_loss0.015567 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 22/50 Batch 0000/78 |Train_ELBO 6850.373535 |Valid_ELBO6746.251465 |Valid_loss0.018117 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 22/50 Batch 0078/78 |Train_ELBO 6565.415039 |Valid_ELBO6528.925293 |Valid_loss0.017823 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 23/50 Batch 0000/78 |Train_ELBO 6794.489746 |Valid_ELBO6706.114258 |Valid_loss0.018559 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 23/50 Batch 0078/78 |Train_ELBO 6865.992188 |Valid_ELBO6768.558594 |Valid_loss0.022826 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 24/50 Batch 0000/78 |Train_ELBO 6608.339844 |Valid_ELBO6610.315918 |Valid_loss0.018565 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 24/50 Batch 0078/78 |Train_ELBO 6850.762695 |Valid_ELBO6863.071777 |Valid_loss0.018728 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 25/50 Batch 0000/78 |Train_ELBO 6581.676758 |Valid_ELBO6409.171387 |Valid_loss0.016217 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 25/50 Batch 0078/78 |Train_ELBO 6431.562500 |Valid_ELBO6489.094727 |Valid_loss0.018561 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 26/50 Batch 0000/78 |Train_ELBO 6915.482910 |Valid_ELBO6740.260254 |Valid_loss0.013556 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 26/50 Batch 0078/78 |Train_ELBO 6813.872070 |Valid_ELBO6817.107910 |Valid_loss0.019042 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 27/50 Batch 0000/78 |Train_ELBO 6609.993652 |Valid_ELBO6530.513672 |Valid_loss0.012769 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 27/50 Batch 0078/78 |Train_ELBO 6902.256348 |Valid_ELBO6782.747070 |Valid_loss0.016065 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 28/50 Batch 0000/78 |Train_ELBO 6850.326660 |Valid_ELBO6763.510254 |Valid_loss0.012901 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 28/50 Batch 0078/78 |Train_ELBO 6938.520996 |Valid_ELBO6742.083008 |Valid_loss0.015771 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 29/50 Batch 0000/78 |Train_ELBO 6850.476562 |Valid_ELBO6644.764160 |Valid_loss0.015225 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 29/50 Batch 0078/78 |Train_ELBO 6700.850098 |Valid_ELBO6625.269043 |Valid_loss0.021304 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 30/50 Batch 0000/78 |Train_ELBO 6375.943359 |Valid_ELBO6407.364746 |Valid_loss0.016383 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 30/50 Batch 0078/78 |Train_ELBO 6703.828125 |Valid_ELBO6721.024902 |Valid_loss0.014191 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 31/50 Batch 0000/78 |Train_ELBO 6716.920410 |Valid_ELBO6521.935059 |Valid_loss0.023157 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 31/50 Batch 0078/78 |Train_ELBO 6895.214844 |Valid_ELBO6893.174316 |Valid_loss0.025585 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 32/50 Batch 0000/78 |Train_ELBO 6874.211914 |Valid_ELBO6907.306152 |Valid_loss0.018675 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 32/50 Batch 0078/78 |Train_ELBO 6594.774902 |Valid_ELBO6621.229980 |Valid_loss0.020034 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 33/50 Batch 0000/78 |Train_ELBO 6635.993164 |Valid_ELBO6483.334473 |Valid_loss0.015424 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 33/50 Batch 0078/78 |Train_ELBO 6736.657227 |Valid_ELBO6675.279785 |Valid_loss0.024734 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 34/50 Batch 0000/78 |Train_ELBO 6951.983887 |Valid_ELBO6789.493652 |Valid_loss0.013690 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 34/50 Batch 0078/78 |Train_ELBO 7082.897949 |Valid_ELBO7011.916504 |Valid_loss0.025514 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 35/50 Batch 0000/78 |Train_ELBO 6621.746094 |Valid_ELBO6392.509277 |Valid_loss0.013437 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 35/50 Batch 0078/78 |Train_ELBO 6548.109863 |Valid_ELBO6579.333496 |Valid_loss0.016843 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 36/50 Batch 0000/78 |Train_ELBO 6596.330566 |Valid_ELBO6496.756348 |Valid_loss0.016164 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 36/50 Batch 0078/78 |Train_ELBO 6710.928223 |Valid_ELBO6734.764160 |Valid_loss0.024704 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 37/50 Batch 0000/78 |Train_ELBO 6666.230469 |Valid_ELBO6620.939941 |Valid_loss0.013627 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 37/50 Batch 0078/78 |Train_ELBO 6622.105469 |Valid_ELBO6596.415039 |Valid_loss0.016632 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 38/50 Batch 0000/78 |Train_ELBO 6359.133301 |Valid_ELBO6275.318848 |Valid_loss0.015309 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 38/50 Batch 0078/78 |Train_ELBO 6474.694336 |Valid_ELBO6409.854004 |Valid_loss0.015385 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 39/50 Batch 0000/78 |Train_ELBO 6855.176758 |Valid_ELBO6784.460449 |Valid_loss0.019030 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 39/50 Batch 0078/78 |Train_ELBO 6968.439941 |Valid_ELBO6939.591309 |Valid_loss0.014377 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 40/50 Batch 0000/78 |Train_ELBO 6352.549316 |Valid_ELBO6247.831055 |Valid_loss0.012004 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 40/50 Batch 0078/78 |Train_ELBO 6428.852051 |Valid_ELBO6323.607910 |Valid_loss0.013674 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 41/50 Batch 0000/78 |Train_ELBO 6716.557129 |Valid_ELBO6605.700195 |Valid_loss0.016283 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 41/50 Batch 0078/78 |Train_ELBO 6582.249512 |Valid_ELBO6631.780762 |Valid_loss0.015231 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 42/50 Batch 0000/78 |Train_ELBO 6588.265625 |Valid_ELBO6427.128418 |Valid_loss0.012368 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 42/50 Batch 0078/78 |Train_ELBO 6752.515625 |Valid_ELBO6581.389160 |Valid_loss0.011886 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 43/50 Batch 0000/78 |Train_ELBO 6533.783203 |Valid_ELBO6330.706543 |Valid_loss0.010533 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 43/50 Batch 0078/78 |Train_ELBO 6651.394043 |Valid_ELBO6751.131348 |Valid_loss0.025546 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 44/50 Batch 0000/78 |Train_ELBO 6702.350098 |Valid_ELBO6606.651855 |Valid_loss0.018759 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 44/50 Batch 0078/78 |Train_ELBO 6798.774902 |Valid_ELBO6787.687012 |Valid_loss0.014038 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 45/50 Batch 0000/78 |Train_ELBO 6674.696777 |Valid_ELBO6527.374512 |Valid_loss0.013781 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 45/50 Batch 0078/78 |Train_ELBO 6583.417480 |Valid_ELBO6562.353027 |Valid_loss0.013165 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 46/50 Batch 0000/78 |Train_ELBO 6458.924805 |Valid_ELBO6213.823242 |Valid_loss0.014240 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 46/50 Batch 0078/78 |Train_ELBO 6730.912598 |Valid_ELBO6807.007812 |Valid_loss0.020019 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 47/50 Batch 0000/78 |Train_ELBO 6733.323730 |Valid_ELBO6570.724121 |Valid_loss0.010650 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 47/50 Batch 0078/78 |Train_ELBO 6511.565918 |Valid_ELBO6476.315918 |Valid_loss0.016996 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 48/50 Batch 0000/78 |Train_ELBO 6709.521973 |Valid_ELBO6668.758789 |Valid_loss0.012869 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 48/50 Batch 0078/78 |Train_ELBO 6615.548340 |Valid_ELBO6595.341309 |Valid_loss0.014570 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 49/50 Batch 0000/78 |Train_ELBO 6225.087402 |Valid_ELBO6095.284668 |Valid_loss0.005698 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 49/50 Batch 0078/78 |Train_ELBO 6752.459473 |Valid_ELBO6573.455566 |Valid_loss0.013764 |Valid_accuary1.000000 |Leaarning_rate0.001000

# %% [markdown]
# # 2. Use the oringinal signal to Generate>>>>>>

# %%
vae = torch.load('vae_all_signals_1002_scale_unscale_11dim_half_sample.pkl').to(device)

# %%
import torch.utils.data

batch_size = 10
test_loader = data_loader

vae=vae.to(device)


recon_signals=[]
latent_space=[]

for iteration, test in enumerate(test_loader):
    test = test.view(test.size(0), -1)
    test = test.to(device).float()
    test_recon_x, test_mean, test_log_var, test_z = vae(test)
    test_recon_x = test_recon_x.view(batch_size, 1002, 11)
    test_recon_x=test_recon_x.cpu().detach().numpy()
    latent_space=test_z.cpu().detach().numpy()

    recon_signals.extend(test_recon_x)
#     latent_space.extend(latent_space)
    
#     if iteration ==10:
#         break
    
recon_signals = np.array(recon_signals)
latent_space = np.array(latent_space)

# %%
print(type(recon_signals[0]))
print(recon_signals[0])

print(len(recon_signals))
print(len(recon_signals[0]))
# print(recon_signals)
# Out:
# <class 'numpy.ndarray'>
# [[0.806066   0.28991812 0.43047422 ... 0.692692   0.62185866 0.4451958 ]
#  [0.80841225 0.28362596 0.44480765 ... 0.61167747 0.57493544 0.4479261 ]
#  [0.8084134  0.2921921  0.43491432 ... 0.6182355  0.5562244  0.4431962 ]
#  ...
#  [0.8147527  0.29297036 0.4893443  ... 0.5962143  0.6024359  0.44349796]
#  [0.75206363 0.38476786 0.4276419  ... 0.61256367 0.585504   0.41066846]
#  [0.03595157 0.01376674 0.02276231 ... 0.028314   0.02530576 0.01228319]]
# 790
# 1002

# %%
# for i in range(len(recon_signals[0])):
#     recon_signals[:,i]=preprocessing.minmax_scale(
#         recon_signals[:,i], feature_range=(np.min(sides_3_trials[:,i]),np.max(sides_3_trials[:,i])))


# # recon_signals = un_normalize(recon_signals, sides_3_trials)
# generate_signals = recon_signals

# np.min(sides_3_trials[:,i])

# %% [markdown]
# ## 2.1 Change shape

# %%
generate_signals=[]
for trial in recon_signals:
    generate_signals.extend(trial)
generate_signals = np.array(generate_signals)

print(np.shape(generate_signals))
print(len(generate_signals))
# Out:
# (791580, 11)
# 791580

# %% [markdown]
# ## 2.1 Un pre-process(here we can select to train use normalize or scale and also generate)

# %%
for i in range(len(generate_signals[0])):
    generate_signals[:,i]=preprocessing.minmax_scale(
        generate_signals[:,i], feature_range=(np.min(sides_3[:,i]),np.max(sides_3[:,i])))
    
generated_signals=generate_signals

print(generated_signals[100])
# Out:
# [ 6.3142395e-03 -3.4319726e-03  2.7468632e-06 -1.6681962e-02
#  -9.1231346e-02  1.9831924e+00  5.2576828e-01  4.0359020e-02
#   4.2343855e-02  1.3251141e-02  7.4559692e+02]

# %%
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt

cmap=plt.cm.get_cmap(plt.cm.viridis,143)


# plt.rcParams['font.size'] = 11.
# plt.rcParams['font.family'] = 'Comic Sans MS'
# plt.rcParams['axes.labelsize'] = 15.
# plt.rcParams['xtick.labelsize'] = 10.
# plt.rcParams['ytick.labelsize'] = 10.

plt.figure(figsize=(15,10))



sides = generated_signals
print(len(sides))

first = 0
slip = 1200

# Peg_Position_x = sides[:,0]
Peg_Position_x = sides[:,0][first:slip]
# Peg_Position_x = sides[:,0][0:10:slip]

# Peg_Position_y = sides[:,1]
Peg_Position_y = sides[:,1][first:slip]
# Peg_Position_y = sides[:,1][0:10:slip]

# Peg_Position_z = sides[:,2]
Peg_Position_z = sides[:,2][first:slip]
# Peg_Position_z = sides[:,2][0:10:slip]

# Angle = sides[:,3]
Angle = sides[:,3][first:slip]
# Angle = sides[:,3][0:10:slip]

# Force_x = sides[:,4]
Force_x = sides[:,4][first:slip]
# Force_x = sides[:,4][0:10:slip]

# Force_y = sides[:,5]
Force_y = sides[:,5][first:slip]
# Force_y = sides[:,5][0:10:slip]

# Force_z = sides[:,6]
Force_z = sides[:,6][first:slip]
# Force_z = sides[:,6][0:10:slip]

# Moment_x = sides[:,7]
Moment_x = sides[:,7][first:slip]
# Moment_x = sides[:,7][0:10:slip]

# Moment_y = sides[:,8]
Moment_y = sides[:,8][first:slip]
# Moment_y = sides[:,8][0:10:slip]

# Moment_z = sides[:,9]
Moment_z = sides[:,9][first:slip]
# Moment_z = sides[:,9][0:10:slip]


# # Time = sides[:,10]
# Time = sides[:,10][first:slip]
# # Time = sides[:,10][0:10:slip]

# # Counter = sides[:,11]
# Counter = sides[:,11][first:slip]
# # Counter = sides[:,11][0:10:slip]

# # print(Counter[1001])
# print(min(Counter))
# print(max(Counter))


# x = Time
x = np.linspace(0,len(Moment_z),len(Moment_z))

plt.plot(x, Force_x, marker='o', linestyle='-', markersize=2, linewidth=1, label='Force_x')
plt.plot(x, Force_y, marker='o', linestyle='-', markersize=2, linewidth=1, label='Force_y')
plt.plot(x, Force_z, marker='o', linestyle='-', markersize=2, linewidth=1, label='Force_z')

plt.plot(x, Moment_x, marker='o', linestyle='-', markersize=2, linewidth=1, label='Moment_x')
plt.plot(x, Moment_y, marker='o', linestyle='-', markersize=2, linewidth=1, label='Moment_y')
plt.plot(x, Moment_z, marker='o', linestyle='-', markersize=2, linewidth=1, label='Moment_z')

plt.plot(x, Peg_Position_x, marker='o', linestyle='-', markersize=2, linewidth=1, label='Peg_Position_x')
plt.plot(x, Peg_Position_y, marker='o', linestyle='-', markersize=2, linewidth=1, label='Peg_Position_y')
plt.plot(x, Peg_Position_z, marker='o', linestyle='-', markersize=2, linewidth=1, label='Peg_Position_z')

plt.plot(x, Angle, marker='o', linestyle='-', markersize=2, linewidth=1, label='Angle')
# plt.plot(x, Counter, marker='o', linestyle='-', markersize=2, linewidth=1, label='Counter')


plt.xlabel('Times')
plt.ylabel('Signals')
plt.title('Generate Force Torque Signals(3 Siles)')
plt.legend(loc='lower right')
# plt.savefig("peg_position_and_angle_mini_generate.png")
plt.show()
# Out:
# 791580

# %% [markdown]
# # 3. Use the random latent space to Generate>>>>>>

# %%
print(latent_space)

import matplotlib.pyplot as plt
import numpy as np
X = latent_space[:,0]
Y = latent_space[:,1]

colors = np.arctan(Y,X) # color

plt.scatter(X, Y, s=75, c=colors, alpha=.5)
# Out:
# [[ 2.2781758   5.389389  ]
#  [ 1.3864543  -2.6908922 ]
#  [ 1.915371    1.297396  ]
#  [ 1.5064381   0.95979726]
#  [-1.134978    2.251744  ]
#  [-3.3203897  -1.5228735 ]
#  [-0.3100806   0.9678489 ]
#  [-4.066669    0.11057717]
#  [ 2.8494024  -4.694054  ]
#  [ 1.0294836  -0.17602673]]

# %%
# batch_size = 10
z = torch.randn([batch_size, 2]).to(device)
# z = torch.FloatTensor(latent_space).to(device)


visual_z = z.cpu().numpy()
import matplotlib.pyplot as plt
import numpy as np
X = visual_z[:,0]
Y = visual_z[:,1]

colors = np.arctan(Y,X) # color

plt.scatter(X, Y, s=75, c=colors, alpha=.5)
plt.xlim(-2,4)
plt.ylim(-2,4)

print(z)
# Out:
# tensor([[-0.0790,  0.9266],
#         [-1.3997,  0.6830],
#         [ 0.5215, -0.5850],
#         [ 0.1291,  0.7839],
#         [-0.5814,  0.9015],
#         [ 0.3974, -0.0237],
#         [ 0.4423, -0.9384],
#         [-0.6130, -0.1314],
#         [ 0.8935,  0.7113],
#         [ 1.2419, -0.7911]], device='cuda:0')

# %%
recon_x = vae.decoder(z)

print(type(recon_x[0]))
print(recon_x[0])

print(len(recon_x))
print(len(recon_x[0]))

print(recon_x[0])
# Out:
# <class 'torch.Tensor'>
# tensor([0.7321, 0.1565, 0.4887,  ..., 0.0140, 0.0141, 0.0143], device='cuda:0',
#        grad_fn=<SelectBackward>)
# 10
# 11022
# tensor([0.7321, 0.1565, 0.4887,  ..., 0.0140, 0.0141, 0.0143], device='cuda:0',
#        grad_fn=<SelectBackward>)

# %%
recon_x = recon_x.view(batch_size,1002,11)
# generate_signals = recon_x.cpu().detach().numpy()

z_generate_signals=[]
for trial in recon_x:
    trial = trial.cpu().detach().numpy()
    z_generate_signals.extend(trial)
z_generate_signals = np.array(z_generate_signals)


# print(np.shape(generate_signals))
print(len(z_generate_signals))
# print(generate_signals[0])
# print(type(generate_signals))
# Out:
# 10020

# %%
for i in range(len(z_generate_signals[0])):
    z_generate_signals[:,i]=preprocessing.minmax_scale(
        z_generate_signals[:,i], feature_range=(np.min(sides_3[:,i]),np.max(sides_3[:,i])))
    
z_generated_signals=z_generate_signals

print(len(z_generated_signals))
print(np.shape(z_generated_signals))
# Out:
# 10020
# (10020, 11)

# %%
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt

cmap=plt.cm.get_cmap(plt.cm.viridis,143)


# plt.rcParams['font.size'] = 11.
# plt.rcParams['font.family'] = 'Comic Sans MS'
# plt.rcParams['axes.labelsize'] = 15.
# plt.rcParams['xtick.labelsize'] = 10.
# plt.rcParams['ytick.labelsize'] = 10.

plt.figure(figsize=(15,10))



sides = z_generate_signals
print(len(sides))

slip = 1200

# Peg_Position_x = sides[:,0]
Peg_Position_x = sides[:,0][:slip]
# Peg_Position_x = sides[:,0][0:10:slip]

# Peg_Position_y = sides[:,1]
Peg_Position_y = sides[:,1][:slip]
# Peg_Position_y = sides[:,1][0:10:slip]

# Peg_Position_z = sides[:,2]
Peg_Position_z = sides[:,2][:slip]
# Peg_Position_z = sides[:,2][0:10:slip]

# Angle = sides[:,3]
Angle = sides[:,3][:slip]
# Angle = sides[:,3][0:10:slip]

# Force_x = sides[:,4]
Force_x = sides[:,4][:slip]
# Force_x = sides[:,4][0:10:slip]

# Force_y = sides[:,5]
Force_y = sides[:,5][:slip]
# Force_y = sides[:,5][0:10:slip]

# Force_z = sides[:,6]
Force_z = sides[:,6][:slip]
# Force_z = sides[:,6][0:10:slip]

# Moment_x = sides[:,7]
Moment_x = sides[:,7][:slip]
# Moment_x = sides[:,7][0:10:slip]

# Moment_y = sides[:,8]
Moment_y = sides[:,8][:slip]
# Moment_y = sides[:,8][0:10:slip]

# Moment_z = sides[:,9]
Moment_z = sides[:,9][:slip]
# Moment_z = sides[:,9][0:10:slip]

x = np.linspace(0,len(Moment_z),len(Moment_z))

plt.plot(x, Force_x, marker='o', linestyle='-', markersize=2, linewidth=1, label='Force_x')
plt.plot(x, Force_y, marker='o', linestyle='-', markersize=2, linewidth=1, label='Force_y')
plt.plot(x, Force_z, marker='o', linestyle='-', markersize=2, linewidth=1, label='Force_z')

plt.plot(x, Moment_x, marker='o', linestyle='-', markersize=2, linewidth=1, label='Moment_x')
plt.plot(x, Moment_y, marker='o', linestyle='-', markersize=2, linewidth=1, label='Moment_y')
plt.plot(x, Moment_z, marker='o', linestyle='-', markersize=2, linewidth=1, label='Moment_z')

plt.plot(x, Peg_Position_x, marker='o', linestyle='-', markersize=2, linewidth=1, label='Peg_Position_x')
plt.plot(x, Peg_Position_y, marker='o', linestyle='-', markersize=2, linewidth=1, label='Peg_Position_y')
plt.plot(x, Peg_Position_z, marker='o', linestyle='-', markersize=2, linewidth=1, label='Peg_Position_z')

plt.plot(x, Angle, marker='o', linestyle='-', markersize=2, linewidth=1, label='Angle')
# plt.plot(x, Counter, marker='o', linestyle='-', markersize=2, linewidth=1, label='Counter')


plt.xlabel('Times')
plt.ylabel('Signals')
plt.title('Force Torque Signals(3 Siles)')
plt.legend(loc='lower right')
plt.show()
# Out:
# 10020

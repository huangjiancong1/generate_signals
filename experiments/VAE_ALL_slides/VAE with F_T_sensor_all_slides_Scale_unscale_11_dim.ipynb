# %% [markdown]
# ## Use scale to pre-processing 11dim with time signals

# %% [markdown]
# ## 1.Pre-processing

# %%
import os
import time
import torch
import argparse
import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
from torchvision import transforms
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader
from collections import defaultdict
import torch.multiprocessing as mp
import torch.utils.data
import torch
import numpy as np
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler
import torch.nn as nn
import numpy

from sklearn import preprocessing

from models_11dim import VAE


device = torch.device('cuda:0')

# convert data to torch.FloatTensor
transform = transforms.ToTensor()

# load the training and test datasets
# train_data = datasets.MNIST(root='data', train=True,
#                                    download=True, transform=transform)
# test_data = datasets.MNIST(root='data', train=False,
#                                   download=True, transform=transform)

# data_loader = DataLoader(
#     dataset=dataset, batch_size=args.batch_size, shuffle=True)
# print(len(train_data))

# dataset = MNIST(
#     root='data', train=True, transform=transforms.ToTensor(),
#     download=True)


sides_3 = np.load('../data/force_torque_sensor/Dataset/3_sides/Data/data.npy')
sides_4 = np.load('../data/force_torque_sensor/Dataset/4_sides/Data/data.npy')
sides_5 = np.load('../data/force_torque_sensor/Dataset/5_sides/Data/data.npy')
sides_6 = np.load('../data/force_torque_sensor/Dataset/6_sides/Data/data.npy')
sides_200 = np.load('../data/force_torque_sensor/Dataset/200_sides/Data/data.npy')

# %%
# def feature_normalize(data):
#     mu = np.mean(data,axis=0)
#     std = np.std(data,axis=0)
#     return (data - mu)/std

# def un_normalize(normalized_data, input_data):
#     mu = np.mean(input_data,axis=0)
#     std = np.std(input_data,axis=0)
#     return normalized_data*std+mu

# %%
def extract_trials(x, n):
#     x = feature_normalize(x)
    x = preprocessing.minmax_scale(x, feature_range=(0,1))
    trials=[]
    trial=[]
    compare=0
    for sig in x:
        trial.append(sig[0:n])
        if sig[11] <= compare:
            d = 1002 - len(trial)
            if d >0:
                for i in range(d):
                    trial.append(np.zeros(len(sig[0:n])))
            trials.append(trial)
            trial=[]
        compare=sig[11]
    trials = np.array(trials)
    return trials

# %%
dim=11 # without select the counter signal

sides_3_trials = extract_trials(sides_3, dim)
# sides_4_trials = extract_trials(sides_4, num)
# sides_5_trials = extract_trials(sides_5, num)
# sides_6_trials = extract_trials(sides_6, num)
# sides_200_trials = extract_trials(sides_200, num)




print(sides_3_trials[1580][999])

print(np.shape(sides_3_trials))
print(len(sides_3_trials[1000]))
print(sides_3_trials[1000])
# Out:
# [0.99409463 0.81367002 0.48168194 0.99903415 0.62487198 0.29022964
#  0.95047635 0.82071828 0.62483573 0.633718   0.99873658]
# (1583, 1002, 11)
# 1002
# [[0.99761829 0.35669136 0.6230216  ... 0.65169391 0.60907035 0.63171194]
#  [0.99761829 0.35669136 0.6230216  ... 0.64997979 0.57950256 0.63171194]
#  [0.99761829 0.35669136 0.6230216  ... 0.61341184 0.57412659 0.63171194]
#  ...
#  [0.99761829 0.35669136 0.6230216  ... 0.6076981  0.59563043 0.63171194]
#  [0.99598465 0.44840978 0.51779794 ... 0.67270165 0.65831302 0.63234365]
#  [0.         0.         0.         ... 0.         0.         0.        ]]

# %%
sides_3_trials = sides_3_trials[0:1580]
dataset = sides_3_trials

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 10

data_loader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True)
train_loader = data_loader
valid_loader = data_loader
test_loader = data_loader

# %%
# import matplotlib.pyplot as plt
# %matplotlib inline
    
# # obtain one batch of training images
# dataiter = iter(data_loader)
# images = dataiter.next()
# images = images.numpy()

# # get one image from the batch
# img = np.squeeze(images[0])

# fig = plt.figure(figsize = (5,500)) 
# ax = fig.add_subplot(111)
# ax.imshow(img, cmap='gray')

# %% [markdown]
# ## Loss function

# %%
def loss_fn(recon_x, x, mean, log_var):
    BCE = torch.nn.functional.binary_cross_entropy(recon_x.view(-1, 1002*11), x.view(-1, 1002*11), reduction='sum')
    KLD = -0.5 * torch.sum(1 + log_var - mean.pow(2) - log_var.exp())
    # elbo = recon_loss + self.beta * D_kl
    elbo = (BCE + KLD)/ x.size(0)
    return elbo

# %%
seed = 0
epochs = 50
latent_size = 2
num_processes = 2
learning_rate = 0.001
print_every = 100


vae = VAE(latent_size=latent_size).float().to(device)

# vae = VAE(
#     encoder_layer_sizes=encoder_layer_sizes,
#     latent_size=latent_size,
#     decoder_layer_sizes=decoder_layer_sizes).to(device)

use_cuda = torch.cuda.is_available
if use_cuda:
    vae.to(device)

logs = defaultdict(list)
    
epochs = epochs
for epoch in range(epochs):
    lr_havel = learning_rate
    optimizer = torch.optim.Adam(vae.parameters(), lr=lr_havel)
    
    for iteration, data in enumerate(train_loader):
        signals = data
        signals = signals.view(signals.size(0), -1)
        if use_cuda:
            signals = signals.to(device).float()
        else:
            signals = signals.float()

        optimizer.zero_grad()
        recon_x, mean, log_var, z = vae(signals)
        elbo = loss_fn(recon_x, signals, mean, log_var)
        loss = elbo
        loss.backward()
        optimizer.step()

        logs['loss'].append(loss.item())

        if iteration % print_every == 0 or iteration == len(train_loader)-1:
            valid_correct = 0
            valid_total = 0
            test_correct = 0
            test_total = 0

            for valid_data in valid_loader:
                valid = valid_data
                valid = signals.view(valid.size(0), -1)
                if use_cuda:
                    input_valid = valid.to(device).float()
                else:
                    input_valid = valid.float()
                valid_recon_x, valid_mean, valid_log_var, valid_z = vae(input_valid)
                valid_elbo = loss_fn(valid_recon_x, input_valid, valid_mean, valid_log_var)
                criterion = nn.MSELoss()
                valid_loss = criterion(valid_recon_x, input_valid)
                logs['valid_elbo'].append(valid_elbo.item())
                logs['valid_loss'].append(valid_loss.item())
                valid_total +=1
                if valid_loss < 0.05:
                    valid_correct += 1
            valid_acc = valid_correct / valid_total  
            print("Epoch {:02d}/{:02d} Batch {:04d}/{:d} |Train_ELBO {:5f} |Valid_ELBO{:5f} |Valid_loss{:5f} |Valid_accuary{:5f} |Leaarning_rate{:5f}".format(
                epoch, epochs, iteration, len(train_loader)-1, loss.item(), valid_elbo.item(), valid_loss.item(), valid_acc, lr_havel))

    lr_havel = lr_havel*0.9
    torch.save(vae, 'vae_all_signals_1002_scale_unscale_11dim.pkl')
# Out:
# Epoch 00/50 Batch 0000/157 |Train_ELBO 7935.142090 |Valid_ELBO7936.153809 |Valid_loss0.067990 |Valid_accuary0.000000 |Leaarning_rate0.001000
# Epoch 00/50 Batch 0100/157 |Train_ELBO 7081.968750 |Valid_ELBO7402.858887 |Valid_loss0.044597 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 00/50 Batch 0157/157 |Train_ELBO 7548.661621 |Valid_ELBO7451.475098 |Valid_loss0.033241 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 01/50 Batch 0000/157 |Train_ELBO 6881.010254 |Valid_ELBO7093.790527 |Valid_loss0.042184 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 01/50 Batch 0100/157 |Train_ELBO 6940.663574 |Valid_ELBO6888.132812 |Valid_loss0.030150 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 01/50 Batch 0157/157 |Train_ELBO 6611.985352 |Valid_ELBO6588.687500 |Valid_loss0.028176 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 02/50 Batch 0000/157 |Train_ELBO 7324.084473 |Valid_ELBO7284.369629 |Valid_loss0.032716 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 02/50 Batch 0100/157 |Train_ELBO 6840.328125 |Valid_ELBO6795.205566 |Valid_loss0.020084 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 02/50 Batch 0157/157 |Train_ELBO 7146.410156 |Valid_ELBO7024.298340 |Valid_loss0.028655 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 03/50 Batch 0000/157 |Train_ELBO 6689.917480 |Valid_ELBO6835.375000 |Valid_loss0.024234 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 03/50 Batch 0100/157 |Train_ELBO 6757.921875 |Valid_ELBO6838.390137 |Valid_loss0.023034 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 03/50 Batch 0157/157 |Train_ELBO 6992.607910 |Valid_ELBO6811.806152 |Valid_loss0.021094 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 04/50 Batch 0000/157 |Train_ELBO 6914.882324 |Valid_ELBO6945.209473 |Valid_loss0.027844 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 04/50 Batch 0100/157 |Train_ELBO 6901.668945 |Valid_ELBO6983.277344 |Valid_loss0.027587 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 04/50 Batch 0157/157 |Train_ELBO 6720.395508 |Valid_ELBO6646.258789 |Valid_loss0.018069 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 05/50 Batch 0000/157 |Train_ELBO 6531.572754 |Valid_ELBO6514.906250 |Valid_loss0.020901 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 05/50 Batch 0100/157 |Train_ELBO 6945.152344 |Valid_ELBO6702.679688 |Valid_loss0.017374 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 05/50 Batch 0157/157 |Train_ELBO 6417.481934 |Valid_ELBO6429.851074 |Valid_loss0.020281 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 06/50 Batch 0000/157 |Train_ELBO 6951.292969 |Valid_ELBO6889.812012 |Valid_loss0.022438 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 06/50 Batch 0100/157 |Train_ELBO 7129.274902 |Valid_ELBO6870.847656 |Valid_loss0.028858 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 06/50 Batch 0157/157 |Train_ELBO 6901.254883 |Valid_ELBO6871.859375 |Valid_loss0.019864 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 07/50 Batch 0000/157 |Train_ELBO 7067.486816 |Valid_ELBO6850.240723 |Valid_loss0.018494 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 07/50 Batch 0100/157 |Train_ELBO 6481.776367 |Valid_ELBO6473.868652 |Valid_loss0.015609 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 07/50 Batch 0157/157 |Train_ELBO 6549.495605 |Valid_ELBO6457.233398 |Valid_loss0.020935 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 08/50 Batch 0000/157 |Train_ELBO 6703.201660 |Valid_ELBO6777.700684 |Valid_loss0.017477 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 08/50 Batch 0100/157 |Train_ELBO 6499.547852 |Valid_ELBO6501.583984 |Valid_loss0.017853 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 08/50 Batch 0157/157 |Train_ELBO 7020.843750 |Valid_ELBO6927.657227 |Valid_loss0.021358 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 09/50 Batch 0000/157 |Train_ELBO 6633.692871 |Valid_ELBO6541.642090 |Valid_loss0.015934 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 09/50 Batch 0100/157 |Train_ELBO 6827.337402 |Valid_ELBO6910.835449 |Valid_loss0.019335 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 09/50 Batch 0157/157 |Train_ELBO 6720.932129 |Valid_ELBO6698.269531 |Valid_loss0.014577 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 10/50 Batch 0000/157 |Train_ELBO 6942.217285 |Valid_ELBO6792.074219 |Valid_loss0.016685 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 10/50 Batch 0100/157 |Train_ELBO 6772.671875 |Valid_ELBO6851.700195 |Valid_loss0.015049 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 10/50 Batch 0157/157 |Train_ELBO 7091.764160 |Valid_ELBO6999.853027 |Valid_loss0.027163 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 11/50 Batch 0000/157 |Train_ELBO 6518.954102 |Valid_ELBO6272.378906 |Valid_loss0.017137 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 11/50 Batch 0100/157 |Train_ELBO 6430.353516 |Valid_ELBO6367.704590 |Valid_loss0.010968 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 11/50 Batch 0157/157 |Train_ELBO 6521.599121 |Valid_ELBO6519.193359 |Valid_loss0.016163 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 12/50 Batch 0000/157 |Train_ELBO 6888.658691 |Valid_ELBO6631.053223 |Valid_loss0.018532 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 12/50 Batch 0100/157 |Train_ELBO 6726.069824 |Valid_ELBO6771.077637 |Valid_loss0.018571 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 12/50 Batch 0157/157 |Train_ELBO 6544.588867 |Valid_ELBO6709.063477 |Valid_loss0.018054 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 13/50 Batch 0000/157 |Train_ELBO 7164.149414 |Valid_ELBO6869.404785 |Valid_loss0.014087 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 13/50 Batch 0100/157 |Train_ELBO 6702.464355 |Valid_ELBO6812.215820 |Valid_loss0.017182 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 13/50 Batch 0157/157 |Train_ELBO 6663.458496 |Valid_ELBO6627.017090 |Valid_loss0.016807 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 14/50 Batch 0000/157 |Train_ELBO 6874.641602 |Valid_ELBO6686.860352 |Valid_loss0.020109 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 14/50 Batch 0100/157 |Train_ELBO 6631.101562 |Valid_ELBO6723.589844 |Valid_loss0.022606 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 14/50 Batch 0157/157 |Train_ELBO 6712.605469 |Valid_ELBO6772.990723 |Valid_loss0.018792 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 15/50 Batch 0000/157 |Train_ELBO 6684.921875 |Valid_ELBO6712.219727 |Valid_loss0.017187 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 15/50 Batch 0100/157 |Train_ELBO 6676.311035 |Valid_ELBO6845.206543 |Valid_loss0.026144 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 15/50 Batch 0157/157 |Train_ELBO 6907.580566 |Valid_ELBO6979.364746 |Valid_loss0.019767 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 16/50 Batch 0000/157 |Train_ELBO 6504.925293 |Valid_ELBO6613.753418 |Valid_loss0.015517 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 16/50 Batch 0100/157 |Train_ELBO 7033.101562 |Valid_ELBO6933.317383 |Valid_loss0.021162 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 16/50 Batch 0157/157 |Train_ELBO 6805.673340 |Valid_ELBO6791.806152 |Valid_loss0.024167 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 17/50 Batch 0000/157 |Train_ELBO 6806.714844 |Valid_ELBO6738.878906 |Valid_loss0.022319 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 17/50 Batch 0100/157 |Train_ELBO 6670.343750 |Valid_ELBO6690.976562 |Valid_loss0.030248 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 17/50 Batch 0157/157 |Train_ELBO 6568.394531 |Valid_ELBO6402.214355 |Valid_loss0.017839 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 18/50 Batch 0000/157 |Train_ELBO 6632.899902 |Valid_ELBO6441.749023 |Valid_loss0.011766 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 18/50 Batch 0100/157 |Train_ELBO 6802.282715 |Valid_ELBO6792.991699 |Valid_loss0.021209 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 18/50 Batch 0157/157 |Train_ELBO 6509.799316 |Valid_ELBO6458.822266 |Valid_loss0.014872 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 19/50 Batch 0000/157 |Train_ELBO 6405.380371 |Valid_ELBO6302.324219 |Valid_loss0.009670 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 19/50 Batch 0100/157 |Train_ELBO 6586.825684 |Valid_ELBO6620.786621 |Valid_loss0.014815 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 19/50 Batch 0157/157 |Train_ELBO 6774.287598 |Valid_ELBO6810.555664 |Valid_loss0.021762 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 20/50 Batch 0000/157 |Train_ELBO 6653.541504 |Valid_ELBO6563.327637 |Valid_loss0.020356 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 20/50 Batch 0100/157 |Train_ELBO 6574.734375 |Valid_ELBO6558.483887 |Valid_loss0.011085 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 20/50 Batch 0157/157 |Train_ELBO 6673.769043 |Valid_ELBO6710.775879 |Valid_loss0.017395 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 21/50 Batch 0000/157 |Train_ELBO 6801.887695 |Valid_ELBO6611.699219 |Valid_loss0.009505 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 21/50 Batch 0100/157 |Train_ELBO 6791.680664 |Valid_ELBO6786.512695 |Valid_loss0.017157 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 21/50 Batch 0157/157 |Train_ELBO 6761.641602 |Valid_ELBO6677.430664 |Valid_loss0.015396 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 22/50 Batch 0000/157 |Train_ELBO 6458.198242 |Valid_ELBO6251.468750 |Valid_loss0.008031 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 22/50 Batch 0100/157 |Train_ELBO 6829.731934 |Valid_ELBO6735.878906 |Valid_loss0.013906 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 22/50 Batch 0157/157 |Train_ELBO 6412.815430 |Valid_ELBO6280.036621 |Valid_loss0.011455 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 23/50 Batch 0000/157 |Train_ELBO 6900.813477 |Valid_ELBO6631.011230 |Valid_loss0.020811 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 23/50 Batch 0100/157 |Train_ELBO 6373.497070 |Valid_ELBO6592.976074 |Valid_loss0.022100 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 23/50 Batch 0157/157 |Train_ELBO 6543.476074 |Valid_ELBO6589.738281 |Valid_loss0.017130 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 24/50 Batch 0000/157 |Train_ELBO 6442.701172 |Valid_ELBO6281.943359 |Valid_loss0.008235 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 24/50 Batch 0100/157 |Train_ELBO 6522.176270 |Valid_ELBO6552.353516 |Valid_loss0.016967 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 24/50 Batch 0157/157 |Train_ELBO 6684.522949 |Valid_ELBO6550.195801 |Valid_loss0.017728 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 25/50 Batch 0000/157 |Train_ELBO 6802.339355 |Valid_ELBO6641.888184 |Valid_loss0.016229 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 25/50 Batch 0100/157 |Train_ELBO 6465.747559 |Valid_ELBO6468.578125 |Valid_loss0.020330 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 25/50 Batch 0157/157 |Train_ELBO 6349.970215 |Valid_ELBO6386.722168 |Valid_loss0.016386 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 26/50 Batch 0000/157 |Train_ELBO 6701.545410 |Valid_ELBO6662.411621 |Valid_loss0.012657 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 26/50 Batch 0100/157 |Train_ELBO 6323.719727 |Valid_ELBO6338.634766 |Valid_loss0.012518 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 26/50 Batch 0157/157 |Train_ELBO 6449.030762 |Valid_ELBO6517.192383 |Valid_loss0.015294 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 27/50 Batch 0000/157 |Train_ELBO 6630.626465 |Valid_ELBO6559.869629 |Valid_loss0.012564 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 27/50 Batch 0100/157 |Train_ELBO 6488.191406 |Valid_ELBO6446.278809 |Valid_loss0.014147 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 27/50 Batch 0157/157 |Train_ELBO 6493.337402 |Valid_ELBO6608.874512 |Valid_loss0.024317 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 28/50 Batch 0000/157 |Train_ELBO 6731.115723 |Valid_ELBO6624.131348 |Valid_loss0.006094 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 28/50 Batch 0100/157 |Train_ELBO 6258.687500 |Valid_ELBO6211.022949 |Valid_loss0.009187 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 28/50 Batch 0157/157 |Train_ELBO 6817.750977 |Valid_ELBO6803.908691 |Valid_loss0.017305 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 29/50 Batch 0000/157 |Train_ELBO 6843.304688 |Valid_ELBO6732.041504 |Valid_loss0.010359 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 29/50 Batch 0100/157 |Train_ELBO 6866.065918 |Valid_ELBO6875.821289 |Valid_loss0.016059 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 29/50 Batch 0157/157 |Train_ELBO 6837.218750 |Valid_ELBO6761.224121 |Valid_loss0.009916 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 30/50 Batch 0000/157 |Train_ELBO 6300.638184 |Valid_ELBO6123.673340 |Valid_loss0.009411 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 30/50 Batch 0100/157 |Train_ELBO 6466.246582 |Valid_ELBO6510.417480 |Valid_loss0.017454 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 30/50 Batch 0157/157 |Train_ELBO 6646.398438 |Valid_ELBO6555.109375 |Valid_loss0.015806 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 31/50 Batch 0000/157 |Train_ELBO 6445.124023 |Valid_ELBO6431.659180 |Valid_loss0.008870 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 31/50 Batch 0100/157 |Train_ELBO 6341.173828 |Valid_ELBO6253.445312 |Valid_loss0.011710 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 31/50 Batch 0157/157 |Train_ELBO 6421.175781 |Valid_ELBO6439.770996 |Valid_loss0.011825 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 32/50 Batch 0000/157 |Train_ELBO 6810.188477 |Valid_ELBO6742.781250 |Valid_loss0.012289 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 32/50 Batch 0100/157 |Train_ELBO 6301.723633 |Valid_ELBO6370.717773 |Valid_loss0.019462 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 32/50 Batch 0157/157 |Train_ELBO 6392.244141 |Valid_ELBO6353.452637 |Valid_loss0.009370 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 33/50 Batch 0000/157 |Train_ELBO 6708.986816 |Valid_ELBO6685.382324 |Valid_loss0.009897 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 33/50 Batch 0100/157 |Train_ELBO 6529.328613 |Valid_ELBO6545.897949 |Valid_loss0.012142 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 33/50 Batch 0157/157 |Train_ELBO 6643.639160 |Valid_ELBO6604.822754 |Valid_loss0.020635 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 34/50 Batch 0000/157 |Train_ELBO 6393.422852 |Valid_ELBO6379.680664 |Valid_loss0.013623 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 34/50 Batch 0100/157 |Train_ELBO 6356.675781 |Valid_ELBO6401.222656 |Valid_loss0.019729 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 34/50 Batch 0157/157 |Train_ELBO 6403.144531 |Valid_ELBO6362.516113 |Valid_loss0.011324 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 35/50 Batch 0000/157 |Train_ELBO 6663.032227 |Valid_ELBO6577.069824 |Valid_loss0.010246 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 35/50 Batch 0100/157 |Train_ELBO 6511.023926 |Valid_ELBO6490.297363 |Valid_loss0.013270 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 35/50 Batch 0157/157 |Train_ELBO 6470.150391 |Valid_ELBO6586.117188 |Valid_loss0.022287 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 36/50 Batch 0000/157 |Train_ELBO 6608.058105 |Valid_ELBO6528.338867 |Valid_loss0.010078 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 36/50 Batch 0100/157 |Train_ELBO 6773.726562 |Valid_ELBO6756.722168 |Valid_loss0.015240 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 36/50 Batch 0157/157 |Train_ELBO 6268.363770 |Valid_ELBO6269.791992 |Valid_loss0.011100 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 37/50 Batch 0000/157 |Train_ELBO 6427.500488 |Valid_ELBO6341.346191 |Valid_loss0.010673 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 37/50 Batch 0100/157 |Train_ELBO 6635.928223 |Valid_ELBO6595.446777 |Valid_loss0.014715 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 37/50 Batch 0157/157 |Train_ELBO 6533.360840 |Valid_ELBO6519.937500 |Valid_loss0.011485 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 38/50 Batch 0000/157 |Train_ELBO 6316.642578 |Valid_ELBO6200.622070 |Valid_loss0.010673 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 38/50 Batch 0100/157 |Train_ELBO 6578.353027 |Valid_ELBO6583.880371 |Valid_loss0.015901 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 38/50 Batch 0157/157 |Train_ELBO 6443.975586 |Valid_ELBO6512.392090 |Valid_loss0.014964 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 39/50 Batch 0000/157 |Train_ELBO 6663.665527 |Valid_ELBO6632.243652 |Valid_loss0.017242 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 39/50 Batch 0100/157 |Train_ELBO 6481.370605 |Valid_ELBO6445.036621 |Valid_loss0.015175 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 39/50 Batch 0157/157 |Train_ELBO 6668.429199 |Valid_ELBO6728.817871 |Valid_loss0.021640 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 40/50 Batch 0000/157 |Train_ELBO 6671.269531 |Valid_ELBO6670.128906 |Valid_loss0.010448 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 40/50 Batch 0100/157 |Train_ELBO 6643.872559 |Valid_ELBO6633.762695 |Valid_loss0.020978 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 40/50 Batch 0157/157 |Train_ELBO 6550.883789 |Valid_ELBO6588.051758 |Valid_loss0.015547 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 41/50 Batch 0000/157 |Train_ELBO 6307.020996 |Valid_ELBO6241.865234 |Valid_loss0.011786 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 41/50 Batch 0100/157 |Train_ELBO 6855.260254 |Valid_ELBO6972.037598 |Valid_loss0.027477 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 41/50 Batch 0157/157 |Train_ELBO 6473.335449 |Valid_ELBO6377.881348 |Valid_loss0.013823 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 42/50 Batch 0000/157 |Train_ELBO 6452.690918 |Valid_ELBO6380.003906 |Valid_loss0.011098 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 42/50 Batch 0100/157 |Train_ELBO 6801.365723 |Valid_ELBO6738.730469 |Valid_loss0.016546 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 42/50 Batch 0157/157 |Train_ELBO 6375.109863 |Valid_ELBO6419.354980 |Valid_loss0.014568 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 43/50 Batch 0000/157 |Train_ELBO 6520.532227 |Valid_ELBO6469.157227 |Valid_loss0.008762 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 43/50 Batch 0100/157 |Train_ELBO 6630.110352 |Valid_ELBO6638.057129 |Valid_loss0.011641 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 43/50 Batch 0157/157 |Train_ELBO 6586.714844 |Valid_ELBO6540.099121 |Valid_loss0.011823 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 44/50 Batch 0000/157 |Train_ELBO 6596.183105 |Valid_ELBO6482.421875 |Valid_loss0.007808 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 44/50 Batch 0100/157 |Train_ELBO 6482.114258 |Valid_ELBO6525.436035 |Valid_loss0.011719 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 44/50 Batch 0157/157 |Train_ELBO 6663.334473 |Valid_ELBO6565.597168 |Valid_loss0.015703 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 45/50 Batch 0000/157 |Train_ELBO 6458.330566 |Valid_ELBO6403.456543 |Valid_loss0.006668 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 45/50 Batch 0100/157 |Train_ELBO 6583.468750 |Valid_ELBO6573.189941 |Valid_loss0.011242 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 45/50 Batch 0157/157 |Train_ELBO 6578.135254 |Valid_ELBO6515.968262 |Valid_loss0.010142 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 46/50 Batch 0000/157 |Train_ELBO 6419.968262 |Valid_ELBO6352.593262 |Valid_loss0.008336 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 46/50 Batch 0100/157 |Train_ELBO 6229.573242 |Valid_ELBO6283.446777 |Valid_loss0.010971 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 46/50 Batch 0157/157 |Train_ELBO 6176.337891 |Valid_ELBO6230.138672 |Valid_loss0.013573 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 47/50 Batch 0000/157 |Train_ELBO 6627.202637 |Valid_ELBO6585.140137 |Valid_loss0.012110 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 47/50 Batch 0100/157 |Train_ELBO 6416.300781 |Valid_ELBO6446.435547 |Valid_loss0.008515 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 47/50 Batch 0157/157 |Train_ELBO 6469.855957 |Valid_ELBO6546.235352 |Valid_loss0.015808 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 48/50 Batch 0000/157 |Train_ELBO 6347.004883 |Valid_ELBO6368.217773 |Valid_loss0.012260 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 48/50 Batch 0100/157 |Train_ELBO 6524.802734 |Valid_ELBO6442.606445 |Valid_loss0.011995 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 48/50 Batch 0157/157 |Train_ELBO 6498.734863 |Valid_ELBO6441.894043 |Valid_loss0.008070 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 49/50 Batch 0000/157 |Train_ELBO 6396.153809 |Valid_ELBO6401.830078 |Valid_loss0.011454 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 49/50 Batch 0100/157 |Train_ELBO 6431.516113 |Valid_ELBO6382.964355 |Valid_loss0.012750 |Valid_accuary1.000000 |Leaarning_rate0.001000
# Epoch 49/50 Batch 0157/157 |Train_ELBO 6605.265137 |Valid_ELBO6626.945312 |Valid_loss0.007235 |Valid_accuary1.000000 |Leaarning_rate0.001000

# %% [markdown]
# # 2. Use the oringinal signal to Generate>>>>>>

# %%
vae = torch.load('vae_all_signals_1002_scale_unscale_11dim.pkl').to(device)

# %%
import torch.utils.data

batch_size = 10
test_loader = data_loader

vae=vae.to(device)


recon_signals=[]
latent_space=[]

for iteration, test in enumerate(test_loader):
    test = test.view(test.size(0), -1)
    test = test.to(device).float()
    test_recon_x, test_mean, test_log_var, test_z = vae(test)
    test_recon_x = test_recon_x.view(batch_size, 1002, 11)
    test_recon_x=test_recon_x.cpu().detach().numpy()
    latent_space=test_z.cpu().detach().numpy()

    recon_signals.extend(test_recon_x)
#     latent_space.extend(latent_space)
    
#     if iteration ==10:
#         break
    
recon_signals = np.array(recon_signals)
latent_space = np.array(latent_space)

# %%
print(type(recon_signals[0]))
print(recon_signals[0])

print(len(recon_signals))
print(len(recon_signals[0]))
# print(recon_signals)
# Out:
# <class 'numpy.ndarray'>
# [[0.43542358 0.17905742 0.45276964 ... 0.6378906  0.6063197  0.2204164 ]
#  [0.43566272 0.17885104 0.4540169  ... 0.6377222  0.58100563 0.21897212]
#  [0.43579316 0.17897244 0.45579836 ... 0.6500587  0.5881304  0.21985452]
#  ...
#  [0.43005842 0.21272416 0.4454812  ... 0.5937395  0.58966637 0.21637398]
#  [0.41951782 0.20481078 0.41689608 ... 0.5412376  0.5034829  0.20370948]
#  [0.00939378 0.01037938 0.01342414 ... 0.01904069 0.01810593 0.00516923]]
# 1580
# 1002

# %%
# for i in range(len(recon_signals[0])):
#     recon_signals[:,i]=preprocessing.minmax_scale(
#         recon_signals[:,i], feature_range=(np.min(sides_3_trials[:,i]),np.max(sides_3_trials[:,i])))


# # recon_signals = un_normalize(recon_signals, sides_3_trials)
# generate_signals = recon_signals

# np.min(sides_3_trials[:,i])

# %% [markdown]
# ## 2.1 Change shape

# %%
generate_signals=[]
for trial in recon_signals:
    generate_signals.extend(trial)
generate_signals = np.array(generate_signals)

print(np.shape(generate_signals))
print(len(generate_signals))
# Out:
# (1583160, 11)
# 1583160

# %% [markdown]
# ## 2.1 Un pre-process(here we can select to train use normalize or scale and also generate)

# %%
for i in range(len(generate_signals[0])):
    generate_signals[:,i]=preprocessing.minmax_scale(
        generate_signals[:,i], feature_range=(np.min(sides_3[:,i]),np.max(sides_3[:,i])))
    
generated_signals=generate_signals

print(generated_signals[100])
# Out:
# [-5.5947714e-04 -5.3370316e-03  1.0561971e-04 -5.3120587e-02
#   2.0759411e+00  4.2785006e+00  7.6521301e-01  1.5932596e-01
#   3.8613176e-01  7.6366708e-02  3.7134833e+02]

# %%
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt

cmap=plt.cm.get_cmap(plt.cm.viridis,143)


# plt.rcParams['font.size'] = 11.
# plt.rcParams['font.family'] = 'Comic Sans MS'
# plt.rcParams['axes.labelsize'] = 15.
# plt.rcParams['xtick.labelsize'] = 10.
# plt.rcParams['ytick.labelsize'] = 10.

plt.figure(figsize=(15,10))



sides = generated_signals
print(len(sides))

first = 0
slip = 1200

# Peg_Position_x = sides[:,0]
Peg_Position_x = sides[:,0][first:slip]
# Peg_Position_x = sides[:,0][0:10:slip]

# Peg_Position_y = sides[:,1]
Peg_Position_y = sides[:,1][first:slip]
# Peg_Position_y = sides[:,1][0:10:slip]

# Peg_Position_z = sides[:,2]
Peg_Position_z = sides[:,2][first:slip]
# Peg_Position_z = sides[:,2][0:10:slip]

# Angle = sides[:,3]
Angle = sides[:,3][first:slip]
# Angle = sides[:,3][0:10:slip]

# Force_x = sides[:,4]
Force_x = sides[:,4][first:slip]
# Force_x = sides[:,4][0:10:slip]

# Force_y = sides[:,5]
Force_y = sides[:,5][first:slip]
# Force_y = sides[:,5][0:10:slip]

# Force_z = sides[:,6]
Force_z = sides[:,6][first:slip]
# Force_z = sides[:,6][0:10:slip]

# Moment_x = sides[:,7]
Moment_x = sides[:,7][first:slip]
# Moment_x = sides[:,7][0:10:slip]

# Moment_y = sides[:,8]
Moment_y = sides[:,8][first:slip]
# Moment_y = sides[:,8][0:10:slip]

# Moment_z = sides[:,9]
Moment_z = sides[:,9][first:slip]
# Moment_z = sides[:,9][0:10:slip]


# # Time = sides[:,10]
# Time = sides[:,10][first:slip]
# # Time = sides[:,10][0:10:slip]

# # Counter = sides[:,11]
# Counter = sides[:,11][first:slip]
# # Counter = sides[:,11][0:10:slip]

# # print(Counter[1001])
# print(min(Counter))
# print(max(Counter))


# x = Time
x = np.linspace(0,len(Moment_z),len(Moment_z))

plt.plot(x, Force_x, marker='o', linestyle='-', markersize=2, linewidth=1, label='Force_x')
plt.plot(x, Force_y, marker='o', linestyle='-', markersize=2, linewidth=1, label='Force_y')
plt.plot(x, Force_z, marker='o', linestyle='-', markersize=2, linewidth=1, label='Force_z')

plt.plot(x, Moment_x, marker='o', linestyle='-', markersize=2, linewidth=1, label='Moment_x')
plt.plot(x, Moment_y, marker='o', linestyle='-', markersize=2, linewidth=1, label='Moment_y')
plt.plot(x, Moment_z, marker='o', linestyle='-', markersize=2, linewidth=1, label='Moment_z')

plt.plot(x, Peg_Position_x, marker='o', linestyle='-', markersize=2, linewidth=1, label='Peg_Position_x')
plt.plot(x, Peg_Position_y, marker='o', linestyle='-', markersize=2, linewidth=1, label='Peg_Position_y')
plt.plot(x, Peg_Position_z, marker='o', linestyle='-', markersize=2, linewidth=1, label='Peg_Position_z')

plt.plot(x, Angle, marker='o', linestyle='-', markersize=2, linewidth=1, label='Angle')
# plt.plot(x, Counter, marker='o', linestyle='-', markersize=2, linewidth=1, label='Counter')


plt.xlabel('Times')
plt.ylabel('Signals')
plt.title('Generate Force Torque Signals(3 Siles)')
plt.legend(loc='lower right')
# plt.savefig("peg_position_and_angle_mini_generate.png")
plt.show()
# Out:
# 1583160

# %% [markdown]
# # 3. Use the random latent space to Generate>>>>>>

# %%
print(latent_space)

import matplotlib.pyplot as plt
import numpy as np
X = latent_space[:,0]
Y = latent_space[:,1]

colors = np.arctan(Y,X) # color

plt.scatter(X, Y, s=75, c=colors, alpha=.5)
# Out:
# [[-0.8329196   0.03203335]
#  [ 2.092458   -1.0201155 ]
#  [-2.807513   -5.3171935 ]
#  [ 0.0516444   2.4571443 ]
#  [ 2.5968      1.6350887 ]
#  [-0.03508773  0.91708845]
#  [ 0.30643865 -0.8499275 ]
#  [ 2.414029    0.41138482]
#  [-3.9364452   1.2222133 ]
#  [-1.6309347  -1.312782  ]]

# %%
# batch_size = 10
z = torch.randn([batch_size, 2]).to(device)
# z = torch.FloatTensor(latent_space).to(device)


visual_z = z.cpu().numpy()
import matplotlib.pyplot as plt
import numpy as np
X = visual_z[:,0]
Y = visual_z[:,1]

colors = np.arctan(Y,X) # color

plt.scatter(X, Y, s=75, c=colors, alpha=.5)
plt.xlim(-2,4)
plt.ylim(-2,4)

print(z)
# Out:
# tensor([[ 0.4024,  0.5545],
#         [-0.5097,  0.9422],
#         [ 0.0132, -0.4125],
#         [ 1.3411,  0.0107],
#         [ 1.5646, -0.5383],
#         [ 0.7417,  0.0331],
#         [-1.8022,  0.3230],
#         [ 0.4059, -0.3087],
#         [ 1.2083,  1.4410],
#         [ 0.8907, -0.5393]], device='cuda:0')

# %%
recon_x = vae.decoder(z)

print(type(recon_x[0]))
print(recon_x[0])

print(len(recon_x))
print(len(recon_x[0]))

print(recon_x[0])
# Out:
# <class 'torch.Tensor'>
# tensor([0.8781, 0.4537, 0.4908,  ..., 0.0032, 0.0031, 0.0015], device='cuda:0',
#        grad_fn=<SelectBackward>)
# 10
# 11022
# tensor([0.8781, 0.4537, 0.4908,  ..., 0.0032, 0.0031, 0.0015], device='cuda:0',
#        grad_fn=<SelectBackward>)

# %%
recon_x = recon_x.view(batch_size,1002,11)
# generate_signals = recon_x.cpu().detach().numpy()

z_generate_signals=[]
for trial in recon_x:
    trial = trial.cpu().detach().numpy()
    z_generate_signals.extend(trial)
z_generate_signals = np.array(z_generate_signals)


# print(np.shape(generate_signals))
print(len(z_generate_signals))
# print(generate_signals[0])
# print(type(generate_signals))
# Out:
# 10020

# %%
for i in range(len(z_generate_signals[0])):
    z_generate_signals[:,i]=preprocessing.minmax_scale(
        z_generate_signals[:,i], feature_range=(np.min(sides_3[:,i]),np.max(sides_3[:,i])))
    
z_generated_signals=z_generate_signals

print(len(z_generated_signals))
print(np.shape(z_generated_signals))
# Out:
# 10020
# (10020, 11)

# %%
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt

cmap=plt.cm.get_cmap(plt.cm.viridis,143)


# plt.rcParams['font.size'] = 11.
# plt.rcParams['font.family'] = 'Comic Sans MS'
# plt.rcParams['axes.labelsize'] = 15.
# plt.rcParams['xtick.labelsize'] = 10.
# plt.rcParams['ytick.labelsize'] = 10.

plt.figure(figsize=(15,10))



sides = z_generate_signals
print(len(sides))

slip = 1200

# Peg_Position_x = sides[:,0]
Peg_Position_x = sides[:,0][:slip]
# Peg_Position_x = sides[:,0][0:10:slip]

# Peg_Position_y = sides[:,1]
Peg_Position_y = sides[:,1][:slip]
# Peg_Position_y = sides[:,1][0:10:slip]

# Peg_Position_z = sides[:,2]
Peg_Position_z = sides[:,2][:slip]
# Peg_Position_z = sides[:,2][0:10:slip]

# Angle = sides[:,3]
Angle = sides[:,3][:slip]
# Angle = sides[:,3][0:10:slip]

# Force_x = sides[:,4]
Force_x = sides[:,4][:slip]
# Force_x = sides[:,4][0:10:slip]

# Force_y = sides[:,5]
Force_y = sides[:,5][:slip]
# Force_y = sides[:,5][0:10:slip]

# Force_z = sides[:,6]
Force_z = sides[:,6][:slip]
# Force_z = sides[:,6][0:10:slip]

# Moment_x = sides[:,7]
Moment_x = sides[:,7][:slip]
# Moment_x = sides[:,7][0:10:slip]

# Moment_y = sides[:,8]
Moment_y = sides[:,8][:slip]
# Moment_y = sides[:,8][0:10:slip]

# Moment_z = sides[:,9]
Moment_z = sides[:,9][:slip]
# Moment_z = sides[:,9][0:10:slip]

x = np.linspace(0,len(Moment_z),len(Moment_z))

plt.plot(x, Force_x, marker='o', linestyle='-', markersize=2, linewidth=1, label='Force_x')
plt.plot(x, Force_y, marker='o', linestyle='-', markersize=2, linewidth=1, label='Force_y')
plt.plot(x, Force_z, marker='o', linestyle='-', markersize=2, linewidth=1, label='Force_z')

plt.plot(x, Moment_x, marker='o', linestyle='-', markersize=2, linewidth=1, label='Moment_x')
plt.plot(x, Moment_y, marker='o', linestyle='-', markersize=2, linewidth=1, label='Moment_y')
plt.plot(x, Moment_z, marker='o', linestyle='-', markersize=2, linewidth=1, label='Moment_z')

plt.plot(x, Peg_Position_x, marker='o', linestyle='-', markersize=2, linewidth=1, label='Peg_Position_x')
plt.plot(x, Peg_Position_y, marker='o', linestyle='-', markersize=2, linewidth=1, label='Peg_Position_y')
plt.plot(x, Peg_Position_z, marker='o', linestyle='-', markersize=2, linewidth=1, label='Peg_Position_z')

plt.plot(x, Angle, marker='o', linestyle='-', markersize=2, linewidth=1, label='Angle')
# plt.plot(x, Counter, marker='o', linestyle='-', markersize=2, linewidth=1, label='Counter')


plt.xlabel('Times')
plt.ylabel('Signals')
plt.title('Force Torque Signals(3 Siles)')
plt.legend(loc='lower right')
plt.show()
# Out:
# 10020
